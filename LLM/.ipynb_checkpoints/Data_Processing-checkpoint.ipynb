# %% [markdown]
# ## Import Required Libraries

# %%
# !pip install contractions
# Out:
# Requirement already satisfied: contractions in /opt/conda/lib/python3.11/site-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in /opt/conda/lib/python3.11/site-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in /opt/conda/lib/python3.11/site-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in /opt/conda/lib/python3.11/site-packages (from textsearch>=0.0.21->contractions) (2.1.0)

# %%
# !pip install langdetect
# Out:
# Requirement already satisfied: langdetect in /opt/conda/lib/python3.11/site-packages (1.0.9)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from langdetect) (1.16.0)

# %%
# !pip install peft
# Out:
# Requirement already satisfied: peft in /opt/conda/lib/python3.11/site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from peft) (24.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from peft) (5.9.8)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /opt/conda/lib/python3.11/site-packages (from peft) (2.3.1.post300)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.11/site-packages (from peft) (4.47.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from peft) (4.66.5)
# Requirement already satisfied: accelerate>=0.21.0 in /opt/conda/lib/python3.11/site-packages (from peft) (1.2.1)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.11/site-packages (from peft) (0.4.5)
# Requirement already satisfied: huggingface-hub>=0.25.0 in /opt/conda/lib/python3.11/site-packages (from peft) (0.25.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.25.0->peft) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.25.0->peft) (2023.6.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.25.0->peft) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.25.0->peft) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.4.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.11/site-packages (from transformers->peft) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/conda/lib/python3.11/site-packages (from transformers->peft) (0.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.25.0->peft) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.25.0->peft) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.25.0->peft) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.25.0->peft) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy->torch>=1.13.0->peft) (1.3.0)

# %%
pip install 'accelerate>=0.26.0'
# Out:
# Requirement already satisfied: accelerate>=0.26.0 in /opt/conda/lib/python3.11/site-packages (1.2.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.26.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.26.0) (24.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.26.0) (5.9.8)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.26.0) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.26.0) (2.3.1.post300)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.26.0) (0.25.2)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.26.0) (0.4.5)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate>=0.26.0) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate>=0.26.0) (2023.6.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate>=0.26.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate>=0.26.0) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate>=0.26.0) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch>=1.10.0->accelerate>=0.26.0) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=1.10.0->accelerate>=0.26.0) (3.4.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=1.10.0->accelerate>=0.26.0) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=1.10.0->accelerate>=0.26.0) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate>=0.26.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate>=0.26.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate>=0.26.0) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate>=0.26.0) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy->torch>=1.10.0->accelerate>=0.26.0) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade transformers
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.11/site-packages (4.47.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /opt/conda/lib/python3.11/site-packages (from transformers) (0.25.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.11/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.11/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/conda/lib/python3.11/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.11/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.11/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'
import gzip
import json
import random
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
import torch
import nltk
import evaluate
import contractions
import re
from langdetect import detect, DetectorFactory
from langdetect.lang_detect_exception import LangDetectException
from transformers import (
    GPT2Tokenizer,
    GPT2LMHeadModel,
    Trainer,
    TrainingArguments,
    DataCollatorForLanguageModeling,
    EarlyStoppingCallback,
    get_linear_schedule_with_warmup
)
from peft import LoraConfig, get_peft_model
import warnings

# Ignore all warnings 
warnings.filterwarnings("ignore")

print('Import Finished')

# Set random seed to ensure reproducibility
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed(42)
# Out:
# 2024-12-21 01:26:36.543277: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-21 01:26:36.557943: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-21 01:26:36.576742: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-21 01:26:36.582446: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-21 01:26:36.595625: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Import Finished

# %% [markdown]
# ## Data Preprocessing

# %%
data_dir = '/home/sagemaker-user/Data/'
model_dir = '/home/sagemaker-user/Models/'
log_dir = '/home/sagemaker-user/Logs/'

# %%
# Data loading and preprocessing functions
def parse(path):
    with gzip.open(path, 'rb') as g:
        for l in g:
            yield eval(l)

def getDF(path):
    df = {}
    for i, d in enumerate(parse(path)):
        df[i] = d
    return pd.DataFrame.from_dict(df, orient='index')

# Load dataset
data_path = data_dir + 'qa_Pet_Supplies.json.gz'  # Make sure this file exists in current directory
df = getDF(data_path)
print("Dataset loaded. First 5 rows example:")
print(df.head())

# Remove missing values
df = df.dropna(subset=['question', 'answer'])

# Text preprocessing function
def preprocess_text(text):
    # Remove HTML tags
    text = re.sub(r'<.*?>', '', text)
    # Replace URLs
    text = re.sub(r'http\S+|www.\S+', '[URL]', text)
    # Remove non-ASCII characters
    text = text.encode('ascii', 'ignore').decode('utf-8')
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    return text

df['question'] = df['question'].apply(preprocess_text)
df['answer'] = df['answer'].apply(preprocess_text)

# Language detection
DetectorFactory.seed = 0

def detect_language(text):
    try:
        return detect(text)
    except LangDetectException:
        return "unknown"

df['question_lang'] = df['question'].apply(detect_language)
df['answer_lang'] = df['answer'].apply(detect_language)

# Count language distribution
question_lang_counts = df['question_lang'].value_counts()
answer_lang_counts = df['answer_lang'].value_counts()

print("Question language distribution:")
print(question_lang_counts)

print("\nAnswer language distribution:")
print(answer_lang_counts)

# Define target languages
target_languages = ['en']

# Filter target languages
filtered_df = df[
    (df['question_lang'].isin(target_languages)) &
    (df['answer_lang'].isin(target_languages))
]

print(f"\nDataset size after filtering: {filtered_df.shape}")

# Expand contractions
def expand_contractions(text):
    return contractions.fix(text)

filtered_df['question'] = filtered_df['question'].apply(expand_contractions)
filtered_df['answer'] = filtered_df['answer'].apply(expand_contractions)

# Load ASIN list
id_asin_path = data_dir+'unique_asin.csv'
if not os.path.exists(id_asin_path):
    raise FileNotFoundError(f"File {id_asin_path} does not exist. Please ensure the file is in the current directory.")
id_asin = pd.read_csv(id_asin_path)

# Filter ASIN
filtered_df = filtered_df[filtered_df['asin'].isin(id_asin['asin'])]
print(f"\nDataset size after ASIN filtering: {filtered_df.shape}")
# Out:
# Dataset loaded. First 5 rows example:
#   questionType        asin    answerTime      unixTime  \
# 0       yes/no  0975412809  Nov 11, 2014  1.415693e+09
# 1       yes/no  0975412809  Apr 13, 2014  1.397372e+09
# 2       yes/no  0975412809  Dec 29, 2014  1.419840e+09
# 3       yes/no  0975412809  Nov 18, 2014  1.416298e+09
# 4       yes/no  0975412809  Nov 11, 2014  1.415693e+09
#
#                                             question answerType  \
# 0  I don't know what grooming tools I need for my...          ?
# 1              Is the bouvier des flandres included?          Y
# 2  Does it specifically cover how to keep male ge...          ?
# 3                    Does it cover anything on cats?          N
# 4  I am having trouble grooming my Irish terrier'...          ?
#
#                                               answer
# 0  Hello. It is very difficult to say "all groomi...
# 1  Yes it is, in the herding group. The book has ...
# 2                        Not that I have seen in it.
# 3                                                 No
# 4  There is a section on Irish terriers in the bo...
# Question language distribution:
# question_lang
# en         35851
# af           175
# fr            83
# nl            65
# de            52
# da            45
# it            43
# ca            42
# cy            39
# tl            33
# no            22
# es            19
# ro            18
# pl            16
# lv            15
# pt            13
# so            13
# sv            10
# et             7
# unknown        6
# sk             6
# fi             6
# hu             6
# sw             6
# vi             4
# sl             3
# sq             2
# hr             2
# lt             2
# cs             1
# id             1
# tr             1
# Name: count, dtype: int64
#
# Answer language distribution:
# answer_lang
# en         34109
# tr           688
# no           386
# af           196
# fr           191
# ca           106
# so            99
# unknown       91
# pt            89
# de            81
# nl            69
# tl            64
# it            54
# es            53
# ro            46
# sw            37
# et            35
# hu            34
# cy            32
# da            26
# id            25
# pl            22
# fi            17
# sk            12
# vi            11
# sv             8
# cs             8
# sl             5
# lt             4
# hr             4
# sq             3
# lv             2
# Name: count, dtype: int64
#
# Dataset size after filtering: (33443, 9)
#
# Dataset size after ASIN filtering: (26575, 9)

# %%
# Remove duplicates and short texts
filtered_df = filtered_df.drop_duplicates(subset=['question','answer'], keep='first')  # Remove duplicates
filtered_df = filtered_df[filtered_df['question'].str.len() > 10]
filtered_df = filtered_df[filtered_df['answer'].str.len() > 10]

# Remove rows containing unexpected characters
filtered_df = filtered_df[~filtered_df['question'].str.contains('[^\x00-\x7F]+')]
filtered_df = filtered_df[~filtered_df['answer'].str.contains('[^\x00-\x7F]+')]

# %%
# Create dialogue text
def create_dialogue_text(row):
    return f"User: {row['question']}\nAssistant: {row['answer']}\n"

filtered_df['text'] = filtered_df.apply(create_dialogue_text, axis=1)

print(f"\nFinal dataset size ready for training: {filtered_df.shape}")
# Out:
# Final dataset size ready for training: (24570, 10)

# %%
filtered_df.head(1)
# Out:
#    questionType        asin    answerTime      unixTime             question  \
# 10   open-ended  4847676011  Oct 17, 2013  1.381993e+09  Where is this made?
#
#    answerType                                             answer  \
# 10        NaN  Made in USA Distributed by: Sergeant's Pet Car...
#
#    question_lang answer_lang  \
# 10            en          en
#
#                                                  text
# 10  User: Where is this made?\nAssistant: Made in ...

# %%
filtered_df.asin.value_counts()
# Out:
# asin
# B0045UGVKY    10
# B000256962    10
# B00006OALW    10
# B0045LAS3O    10
# B0045L29UO    10
#               ..
# B001IMN8GW     1
# B000OAVN0W     1
# B000OXAES6     1
# B000OXAER2     1
# B000QFWCJ6     1
# Name: count, Length: 3520, dtype: int64

# %%
# Get count for each ASIN
asin_counts = filtered_df.asin.value_counts()

# Filter ASINs with count >= 5
filtered_asins = asin_counts[asin_counts >= 5]

# Print results
print(f"Number of ASINs after filtering: {len(filtered_asins)}")
print("\nTop 10 frequent ASINs and their counts:")
print(filtered_asins.head(10))
# Out:
# Number of ASINs after filtering: 2733
#
# Top 10 frequent ASINs and their counts:
# asin
# B0045UGVKY    10
# B000256962    10
# B00006OALW    10
# B0045LAS3O    10
# B0045L29UO    10
# B00H8MDLUE    10
# B004ABHBWK    10
# B0045Y1JGQ    10
# B00006JHRE    10
# B0045Y1JG6    10
# Name: count, dtype: int64

# %%
filtered_df = filtered_df[filtered_df.asin.isin(filtered_asins.index)]

# %%
filtered_df.to_csv(data_dir+'filtered_df.csv')

# %%
data=filtered_df[['asin','question','answer','questionType']]

# %%
# Create dialogue text
def create_dialogue_text(row):
    return f"User: {row['question']}\nAssistant: {row['answer']}\n"

data['dialogue'] = data.apply(create_dialogue_text, axis=1)

# %%
from sklearn.model_selection import train_test_split
# Initialize training and test sets
train_data_list = []
test_data_list = []
# Split for each asin
for asin, group in data.groupby('asin'):
    # If sample size > 1 for this asin, split 80-20 for train/test
    if len(group) > 1:
        train_group, test_group = train_test_split(group, test_size=0.2, random_state=42)
    else:
        # If only one sample, add it to training set
        train_group = group
        test_group = pd.DataFrame(columns=group.columns)  # Empty test set portion
    
    # Add results to training and test set lists
    train_data_list.append(train_group)
    test_data_list.append(test_group)

# Combine all asin training and test sets
train_data = pd.concat(train_data_list).reset_index(drop=True)
test_data = pd.concat(test_data_list).reset_index(drop=True)

# View count comparison of each asin in training and test sets
train_asin_counts = train_data['asin'].value_counts().reset_index()
train_asin_counts.columns = ['asin', 'train_count']

test_asin_counts = test_data['asin'].value_counts().reset_index()
test_asin_counts.columns = ['asin', 'test_count']

# Merge training and test set statistics
asin_counts = pd.merge(train_asin_counts, test_asin_counts, on='asin', how='outer').fillna(0)
asin_counts['train_count'] = asin_counts['train_count'].astype(int)
asin_counts['test_count'] = asin_counts['test_count'].astype(int)

# %%
asin_counts.head()
# Out:
#          asin  train_count  test_count
# 0  4847676011            5           2
# 1  B00004X14K            7           2
# 2  B00006H36X            5           2
# 3  B00006H373            4           1
# 4  B00006JHRE            8           2

# %%
train_data.head()
# Out:
#          asin                                           question  \
# 0  4847676011               does anyone know where this is made?
# 1  4847676011  does this have any type of sugar, grane alchol...
# 2  4847676011  IS this product VEGAN, specifically the glycerin?
# 3  4847676011                     Does this contain citric acid?
# 4  4847676011                          is this a paste or a gel?
#
#                                               answer questionType  \
# 0                     Believe it or not.... the USA!   open-ended
# 1  Here is the list of ingredients: Sorbitol, hyd...   open-ended
# 2  It is my understanding that this product is no...       yes/no
# 3                 it is not listed as an ingredient.       yes/no
# 4                                       It is a gel.   open-ended
#
#                                             dialogue
# 0  User: does anyone know where this is made?\nAs...
# 1  User: does this have any type of sugar, grane ...
# 2  User: IS this product VEGAN, specifically the ...
# 3  User: Does this contain citric acid?\nAssistan...
# 4  User: is this a paste or a gel?\nAssistant: It...

# %%
test_data.head()
# Out:
#          asin                                           question  \
# 0  4847676011                                Where is this made?
# 1  4847676011  Does this have an expiration date? Does it onl...
# 2  B00004X14K                     Are these containers BPA free?
# 3  B00004X14K                                    Is it airtight?
# 4  B00006H36X  Want for something safe for my 18 year old ind...
#
#                                               answer questionType  \
# 0  Made in USA Distributed by: Sergeant's Pet Car...   open-ended
# 1  yes it does have an expiration date. However, ...   open-ended
# 2                               Sorry I do not know!       yes/no
# 3  Not air tight, but it clicks closed. There is ...       yes/no
# 4  the advantage II is a good product. have used ...   open-ended
#
#                                             dialogue
# 0  User: Where is this made?\nAssistant: Made in ...
# 1  User: Does this have an expiration date? Does ...
# 2  User: Are these containers BPA free?\nAssistan...
# 3  User: Is it airtight?\nAssistant: Not air tigh...
# 4  User: Want for something safe for my 18 year o...

# %% [markdown]
# ## Question Types Classifier (temp)

# %%
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
import torch

# Load tokenizer and model
model_name = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForSequenceClassification.from_pretrained(model_name, num_labels=2)  # 2 represents two types: Yes/No and Open-ended
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from torch.utils.data import Dataset

class QuestionTypeDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_length=128):
        self.questions = dataframe['question'].tolist()
        self.labels = dataframe['questionType'].apply(lambda x: 1 if x == 'open-ended' else 0).tolist()  # 1 for open-ended, 0 for yes/no
        self.tokenizer = tokenizer
        self.max_length = max_length
    
    def __len__(self):
        return len(self.questions)
    
    def __getitem__(self, idx):
        question = str(self.questions[idx])
        label = self.labels[idx]
        
        encoding = self.tokenizer.encode_plus(
            question,
            add_special_tokens=True,
            max_length=self.max_length,
            return_token_type_ids=False,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt',
        )
        
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }

# Create dataset objects
train_dataset = QuestionTypeDataset(train_data, tokenizer)
val_dataset = QuestionTypeDataset(test_data, tokenizer)

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir=model_dir+'question_type_classifier',
    num_train_epochs=5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=32,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir=log_dir+'question_type_classifier',
    logging_steps=10,
    evaluation_strategy='epoch',
    save_strategy='epoch',
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model='accuracy',
    greater_is_better=True,
)

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    acc = accuracy_score(labels, preds)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='binary')
    return {
        'accuracy': acc,
        'precision': precision,
        'recall': recall,
        'f1': f1
    }

# %%
# import torch
torch.cuda.empty_cache()

# %%
from transformers import Trainer

# Create dataset objects
train_dataset = QuestionTypeDataset(train_data, tokenizer)
val_dataset = QuestionTypeDataset(test_data, tokenizer)

# Define Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
)

# Start training
trainer.train()
# Out:
#     <div>
#
#       <progress value='4272' max='5265' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4272/5265 24:14 < 05:38, 2.94 it/s, Epoch 4.06/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.067700</td>
#       <td>0.052921</td>
#       <td>0.986924</td>
#       <td>0.987508</td>
#       <td>0.989848</td>
#       <td>0.988677</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.001900</td>
#       <td>0.036589</td>
#       <td>0.992584</td>
#       <td>0.990252</td>
#       <td>0.996954</td>
#       <td>0.993592</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.008000</td>
#       <td>0.023809</td>
#       <td>0.994536</td>
#       <td>0.992595</td>
#       <td>0.997970</td>
#       <td>0.995275</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000500</td>
#       <td>0.032110</td>
#       <td>0.994145</td>
#       <td>0.993921</td>
#       <td>0.995939</td>
#       <td>0.994929</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# Save model and tokenizer
model_save_path = model_dir+'question_type_classifier'
model.save_pretrained(model_save_path)
tokenizer.save_pretrained(model_save_path)

print(f"Question type classifier has been saved to {model_save_path}")

# %%
# Create dialogue text
def create_dialogue_text(row):
    return f"User: {row['question']}\nAssistant: {row['answer']}\n"

filtered_df['dialogue'] = filtered_df.apply(create_dialogue_text, axis=1)

# Group by question type
yes_no_df = filtered_df[filtered_df['questionType'] == 'yes/no']
open_ended_df = filtered_df[filtered_df['questionType'] == 'open-ended']

print(f"Number of Yes/No questions: {yes_no_df.shape[0]}")
print(f"Number of open-ended questions: {open_ended_df.shape[0]}")

# %%
# Save dialogue texts
yes_no_df['dialogue'].to_csv(data_dir+'yes_no_dialogues.txt', index=False, header=False)
open_ended_df['dialogue'].to_csv(data_dir+'open_ended_dialogues.txt', index=False, header=False)

# %%
filtered_df.shape

# %%
from sklearn.model_selection import train_test_split

# Split yes_no_df into training and validation sets
train_yes_no_df, val_yes_no_df = train_test_split(yes_no_df, test_size=0.1, random_state=42)

print(f"Training set size: {train_yes_no_df.shape[0]}")
print(f"Validation set size: {val_yes_no_df.shape[0]}")

# %%
val_yes_no_df['dialogue']

# %%
yes_no_df.head()['dialogue'][13]

# %%
yes_no_df.head()['dialogue'][14]

# %%
# Load GPT-2 tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# Add padding token
tokenizer.pad_token = tokenizer.eos_token

# Reset indices
train_yes_no_df = train_yes_no_df.reset_index(drop=True)
val_yes_no_df = val_yes_no_df.reset_index(drop=True)

# %%
# Clear cache
torch.cuda.empty_cache()

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

class ConversationDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_length=512):
        self.encodings = tokenizer(
            dataframe['dialogue'].tolist(),
            truncation=True,
            max_length=max_length,
            padding=True,
            return_tensors='pt'
        )
        self.input_ids = self.encodings['input_ids']
        self.attention_mask = self.encodings['attention_mask']
    
    def __len__(self):
        return len(self.input_ids)
    
    def __getitem__(self, idx):
        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_mask[idx],
            'labels': self.input_ids[idx],
        }

# Create dataset objects for training and validation sets
train_dataset = ConversationDataset(train_yes_no_df, tokenizer)
val_dataset = ConversationDataset(val_yes_no_df, tokenizer)

# Clear cache
torch.cuda.empty_cache()

# Load pre-trained GPT-2 model
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Resize model's vocabulary to match tokenizer
model.resize_token_embeddings(len(tokenizer))

# Configure LoRA parameters
lora_config = LoraConfig(
    r=8,  # Adjusted to 8
    lora_alpha=16,  # Adjusted to 16
    target_modules=["attn.c_proj"],  # Ensure correct target modules
    lora_dropout=0.1,  # Reduced dropout
    bias="none",
    task_type="CAUSAL_LM"
)

# Wrap model with PEFT
model = get_peft_model(model, lora_config)

# Define training arguments
training_args = TrainingArguments(
    output_dir=model_dir+"gpt2_yes_no",
    overwrite_output_dir=True,
    num_train_epochs=100,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    gradient_accumulation_steps=1,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    save_total_limit=3,
    learning_rate=3e-5,
    weight_decay=0.01,
    logging_steps=500,
    load_best_model_at_end=True,
    metric_for_best_model='eval_loss',
    greater_is_better=False,
    fp16=True,
    report_to="none",
    dataloader_num_workers=16,
    label_smoothing_factor=0.0,
    remove_unused_columns=False,  # Added this line
)

# Calculate total training steps and warm-up steps
total_steps = len(train_dataset) // (training_args.per_device_train_batch_size * training_args.gradient_accumulation_steps) * training_args.num_train_epochs
warmup_steps = int(0.1 * total_steps)

# Define optimizer and scheduler
optimizer = torch.optim.AdamW(model.parameters(), lr=training_args.learning_rate)

scheduler = get_linear_schedule_with_warmup(
    optimizer=optimizer,
    num_warmup_steps=warmup_steps,
    num_training_steps=total_steps
)

# Use DataCollatorForLanguageModeling
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer, mlm=False
)

# Enable early stopping
early_stopping = EarlyStoppingCallback(early_stopping_patience=3)  # Reduced patience steps

# Define Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    optimizers=(optimizer, scheduler),
    callbacks=[early_stopping],
)

# Start training
trainer.train()

print("Model training completed.")

# %%
# Save final model
trainer.save_model(model_dir+"gpt2_yes_no")
tokenizer.save_pretrained(model_dir+"gpt2_yes_no")

# %%
# Create dialogue text
def create_dialogue_text(row):
    return f"User: {row['question']}\nAssistant: {row['answer']}\n"

filtered_df['dialogue'] = filtered_df.apply(create_dialogue_text, axis=1)

# Group by and select open-ended questions
open_ended_df = filtered_df[filtered_df['questionType'] == 'open-ended']

print(f"Number of open-ended questions: {open_ended_df.shape[0]}")

# Save dialogue text
open_ended_df['dialogue'].to_csv(data_dir+'open_ended_dialogues.txt', index=False, header=False)

from sklearn.model_selection import train_test_split

# Split open_ended_df into training and validation sets
train_open_ended_df, val_open_ended_df = train_test_split(open_ended_df, test_size=0.1, random_state=42)

# Save training and validation sets
train_open_ended_df['dialogue'].to_csv(data_dir+'open_ended_dialogues_train.txt', index=False, header=False)
val_open_ended_df['dialogue'].to_csv(data_dir+'open_ended_dialogues_val.txt', index=False, header=False)

print(f"Training set size: {train_open_ended_df.shape[0]}")
print(f"Validation set size: {val_open_ended_df.shape[0]}")

# Load GPT-2 tokenizer
from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments
from transformers import DataCollatorForLanguageModeling
import torch
from torch.utils.data import Dataset
from peft import LoraConfig, get_peft_model

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
tokenizer.pad_token = tokenizer.eos_token

# Reset indices
train_open_ended_df = train_open_ended_df.reset_index(drop=True)
val_open_ended_df = val_open_ended_df.reset_index(drop=True)


class ConversationDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_length=512):
        self.encodings = tokenizer(
            dataframe['dialogue'].tolist(),
            truncation=True,
            max_length=max_length,
            padding=True,
            return_tensors='pt'
        )
        self.input_ids = self.encodings['input_ids']
        self.attention_mask = self.encodings['attention_mask']
    
    def __len__(self):
        return len(self.input_ids)
    
    def __getitem__(self, idx):
        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_mask[idx],
            'labels': self.input_ids[idx],
        }

# Create dataset objects for training and validation sets
train_dataset = ConversationDataset(train_open_ended_df, tokenizer)
val_dataset = ConversationDataset(val_open_ended_df, tokenizer)

# Load pre-trained GPT-2 model
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Resize model's vocabulary to match tokenizer
model.resize_token_embeddings(len(tokenizer))

# Configure LoRA parameters
lora_config = LoraConfig(
    r=8,  # Adjusted to 8
    lora_alpha=16,  # Adjusted to 16
    target_modules=["attn.c_proj"],  # Ensure correct target modules
    lora_dropout=0.1,  # Reduced dropout
    bias="none",
    task_type="CAUSAL_LM"
)

# Wrap model with PEFT
model = get_peft_model(model, lora_config)

# Define training arguments
training_args = TrainingArguments(
    output_dir=model_dir+"gpt2_open_ended",
    overwrite_output_dir=True,
    num_train_epochs=100,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    gradient_accumulation_steps=1,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    save_total_limit=3,
    learning_rate=3e-5,
    weight_decay=0.01,
    logging_steps=500,
    load_best_model_at_end=True,
    metric_for_best_model='eval_loss',
    greater_is_better=False,
    fp16=True,
    report_to="none",
    dataloader_num_workers=16,
    label_smoothing_factor=0.0,
    remove_unused_columns=False,  # Added this line
)

# Use DataCollatorForLanguageModeling
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer, mlm=False
)

# Enable early stopping
from transformers import EarlyStoppingCallback
early_stopping = EarlyStoppingCallback(early_stopping_patience=3)

# Define Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    callbacks=[early_stopping],
)

# Start training
trainer.train()

print("Model training completed.")

# %%
# Save final model
trainer.save_model(model_dir+"gpt2_open_ended")
tokenizer.save_pretrained(model_dir+"gpt2_open_ended")

# %%
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel, TextGenerationPipeline
from sentence_transformers import SentenceTransformer, util
import pandas as pd
import re
import nltk
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge_score import rouge_scorer

# Load sentence transformer model
sbert_model = SentenceTransformer('all-MiniLM-L6-v2')

# Initialize other models and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained(model_dir+'gpt2_yes_no')
tokenizer.pad_token = tokenizer.eos_token

model = GPT2LMHeadModel.from_pretrained(model_dir+'gpt2_yes_no')
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)
model.eval()

generator = TextGenerationPipeline(model=model, tokenizer=tokenizer, device=0 if device == 'cuda' else -1)

# 2. Extract 100 validation samples
sample_size = 100
samples = val_yes_no_df.sample(n=sample_size, random_state=42).reset_index(drop=True)

# Separate user and assistant dialogues
def extract_user_assistant(dialogue):
    user_pattern = r'User:(.*?)\n'
    assistant_pattern = r'Assistant:(.*?)\n'
    
    user_match = re.search(user_pattern, dialogue, re.DOTALL)
    assistant_match = re.search(assistant_pattern, dialogue, re.DOTALL)
    
    user = user_match.group(1).strip() if user_match else ''
    assistant = assistant_match.group(1).strip() if assistant_match else ''
    
    return user, assistant

samples[['User', 'Assistant']] = samples['dialogue'].apply(
    lambda x: pd.Series(extract_user_assistant(x))
)
# Out:
# Device set to use cuda:0

# %%
samples[['User', 'Assistant']]
# Out:
#                                                  User  \
# 0        Does it fit well on all types of handlebars?
# 1      Will these work for a 5.7lb 4 month old puppy?
# 2   Does anyone know where replacement blades, etc...
# 3          Can a Dwarf Hamster escape from this cage?
# 4   Can I use this skimmer with a 110volt power so...
# ..                                                ...
# 95  I have a Ford F150. Is this long enough to cov...
# 96  I cannot find the instructions. Are they avail...
# 97           will this lamp work in dog house safely?
# 98  is this for a small dog? looking for one to fi...
# 99  Will the Fluval FX6 be too powerful for a 105 ...
#
#                                             Assistant
# 0   Well I tried it on a mountain bike and it work...
# 1   I would say yes. I use them on my doxies, most...
# 2   lister blades will work from what i am told fr...
# 3   Very easily. The gaps in the wires are huge. M...
# 4   Yes. It has a standard (American) three-prong ...
# ..                                                ...
# 95  I have a 2006 tundra 4door and it is long enough.
# 96  HI.......the instruction booklet is included i...
# 97  Yes, it should help significantly, but I would...
# 98  Yes. we use it on a 10 pound Dachshund. Will h...
# 99  The fx6 does have two outputs that put water b...
#
# [100 rows x 2 columns]

# %%
# Generate model replies
def generate_answer(question, tokenizer, model, device, max_length=150):
    prompt = f"User: {question}\nAssistant:"
    inputs = tokenizer.encode(prompt, return_tensors='pt').to(device)
    
    with torch.no_grad():
        outputs = model.generate(
            inputs,
            max_length=inputs.shape[1] + max_length,
            temperature=0.6,
            top_p=0.9,
            do_sample=True,
            eos_token_id=tokenizer.encode('\n')[0],
            pad_token_id=tokenizer.eos_token_id
        )
    
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    answer = generated_text.split("Assistant:")[-1].strip()
    answer = answer.split('\n')[0]
    
    return answer

samples['Generated_Assistant'] = samples['User'].apply(lambda x: generate_answer(x, tokenizer, model, device))

# Initialize ROUGE scorer
rouge = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
from bert_score import score as bert_score

def compute_metrics(row):
    actual = row['Assistant']
    generated = row['Generated_Assistant']
    
    # Calculate BLEU score
    smoothie = SmoothingFunction().method4
    bleu_score = sentence_bleu(
        [nltk.word_tokenize(actual.lower())],
        nltk.word_tokenize(generated.lower()),
        smoothing_function=smoothie
    )
    
    # Calculate ROUGE scores
    rouge_scores = rouge.score(actual, generated)
    
    # Calculate semantic similarity (Cosine Similarity)
    cosine_sim = util.pytorch_cos_sim(
        sbert_model.encode(actual, convert_to_tensor=True),
        sbert_model.encode(generated, convert_to_tensor=True)
    ).item()
    
    # Calculate BERTScore
    # P, R, F1 = bert_score([generated], [actual], lang="en", verbose=False)
    # bert_f1_score = F1.mean().item()
    
    # Return single values instead of Series
    return {
        'BLEU': float(bleu_score),  # Ensure float return type
        'ROUGE-1': float(rouge_scores['rouge1'].fmeasure),
        'ROUGE-2': float(rouge_scores['rouge2'].fmeasure),
        'ROUGE-L': float(rouge_scores['rougeL'].fmeasure),
        'Cosine_Similarity': float(cosine_sim),
        # 'BERTScore_F1': bert_f1_score
    }

# Calculate metrics for each sample
metrics_results = []
for idx, row in samples.iterrows():
    metrics = compute_metrics(row)
    metrics_results.append(metrics)

# Convert metrics to DataFrame and add to samples
metrics_df = pd.DataFrame(metrics_results)
samples = samples.assign(**metrics_df)

# Output results for each sample and format metrics
for i in range(sample_size):
    row = samples.iloc[i]
    print(f"\nSample {i+1}:")
    print(f"User: {row['User']}")
    print(f"Actual Assistant: {row['Assistant']}")
    print(f"Generated Assistant: {row['Generated_Assistant']}")
    print("\nMetrics:")
    
    # Convert Series to float format for output formatting
    metrics = {
        'BLEU': float(row['BLEU'].iloc[0] if isinstance(row['BLEU'], pd.Series) else row['BLEU']),
        'ROUGE-1': float(row['ROUGE-1'].iloc[0] if isinstance(row['ROUGE-1'], pd.Series) else row['ROUGE-1']),
        'ROUGE-2': float(row['ROUGE-2'].iloc[0] if isinstance(row['ROUGE-2'], pd.Series) else row['ROUGE-2']),
        'ROUGE-L': float(row['ROUGE-L'].iloc[0] if isinstance(row['ROUGE-L'], pd.Series) else row['ROUGE-L']),
        'Cosine_Similarity': float(row['Cosine_Similarity'].iloc[0] if isinstance(row['Cosine_Similarity'], pd.Series) else row['Cosine_Similarity']),
        # 'BERTScore_F1': float(row['BERTScore_F1'].iloc[0] if isinstance(row['BERTScore_F1'], pd.Series) else row['BERTScore_F1'])
    }
    
    # Output formatted metrics
    print(f"BLEU Score: {metrics['BLEU']:.4f}")
    print(f"ROUGE-1: {metrics['ROUGE-1']:.4f}")
    print(f"ROUGE-2: {metrics['ROUGE-2']:.4f}")
    print(f"ROUGE-L: {metrics['ROUGE-L']:.4f}")
    print(f"Cosine Similarity: {metrics['Cosine_Similarity']:.4f}")
    # print(f"BERTScore (F1): {metrics['BERTScore_F1']:.4f}")
    print("-" * 80)

# Output summary statistics
print("\nSummary Statistics:")
metrics_columns = ['BLEU', 'ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'Cosine_Similarity']
summary_stats = samples[metrics_columns].apply(lambda x: pd.to_numeric(x.iloc[0] if isinstance(x, pd.Series) else x)).describe()
print(summary_stats)
# Out:
# Sample 1:
# User: Does it fit well on all types of handlebars?
# Actual Assistant: Well I tried it on a mountain bike and it worked nicely because the handle bars have a good distance from the wheel. Probably not good with a racing bike where the handle bars are very low.
# Generated Assistant: I have one that fits perfectly.
#
# Metrics:
# BLEU Score: 0.0004
# ROUGE-1: 0.0930
# ROUGE-2: 0.0000
# ROUGE-L: 0.0930
# Cosine Similarity: 0.0680
# --------------------------------------------------------------------------------
#
# Sample 2:
# User: Will these work for a 5.7lb 4 month old puppy?
# Actual Assistant: I would say yes. I use them on my doxies, mostly an eight pound mini dachshund and they work great.
# Generated Assistant: I would not recommend this product as it is not strong enough to hold a dog.
#
# Metrics:
# BLEU Score: 0.0268
# ROUGE-1: 0.1111
# ROUGE-2: 0.0588
# ROUGE-L: 0.1111
# Cosine Similarity: 0.4110
# --------------------------------------------------------------------------------
#
# Sample 3:
# User: Does anyone know where replacement blades, etc. can be purchased???
# Actual Assistant: lister blades will work from what i am told from the person who sharpens blades professionally. If you have someone in your area take the clippers to them and try to match up blades to it
# Generated Assistant: Yes, you can purchase replacement blades from the manufacturer.
#
# Metrics:
# BLEU Score: 0.0061
# ROUGE-1: 0.1778
# ROUGE-2: 0.0465
# ROUGE-L: 0.1333
# Cosine Similarity: 0.5012
# --------------------------------------------------------------------------------
#
# Sample 4:
# User: Can a Dwarf Hamster escape from this cage?
# Actual Assistant: Very easily. The gaps in the wires are huge. My doors were bent out so much my chinchilla almost got out.
# Generated Assistant: I have a Mini-Dwarf that I have not yet tried. I have not tried it yet. I have a Large Hamster that is a bit smaller than mine and has very good strength. I have not tried this cage yet.
#
# Metrics:
# BLEU Score: 0.0095
# ROUGE-1: 0.0323
# ROUGE-2: 0.0000
# ROUGE-L: 0.0323
# Cosine Similarity: 0.3247
# --------------------------------------------------------------------------------
#
# Sample 5:
# User: Can I use this skimmer with a 110volt power source?
# Actual Assistant: Yes. It has a standard (American) three-prong 120V plug.
# Generated Assistant: I have a 110v outlet with a 6.5v fan. I have an 8.5v fan and the fan is on and the fan is off. The only thing that I would suggest is that you use a 3.5v fan.
#
# Metrics:
# BLEU Score: 0.0094
# ROUGE-1: 0.0392
# ROUGE-2: 0.0000
# ROUGE-L: 0.0392
# Cosine Similarity: 0.2555
# --------------------------------------------------------------------------------
#
# Sample 6:
# User: Will my sdf100a collar work on someone else's sdf100a system
# Actual Assistant: Yes, it will.
# Generated Assistant: I have a sdf100a collar that is fitted with a collar that has a collar that is not. I do not know how much it would cost to buy.
#
# Metrics:
# BLEU Score: 0.0108
# ROUGE-1: 0.0625
# ROUGE-2: 0.0000
# ROUGE-L: 0.0625
# Cosine Similarity: 0.0343
# --------------------------------------------------------------------------------
#
# Sample 7:
# User: Can I buy a new battery when the current one is used up?
# Actual Assistant: Yes. The collars take 3 volt batteries. I have changed the batteries and the collars still work great.
# Generated Assistant: I am not sure about this. The battery is not fully charged until it is in the battery compartment.
#
# Metrics:
# BLEU Score: 0.0356
# ROUGE-1: 0.2703
# ROUGE-2: 0.0571
# ROUGE-L: 0.2162
# Cosine Similarity: 0.3109
# --------------------------------------------------------------------------------
#
# Sample 8:
# User: Does this have adjustable Electric shocks for correction especially for large dogs?
# Actual Assistant: There are 5 levels of correction. My dogs are 25 pounds and they jump right up in the air like their are on fire when it is on level 2. Make sure you follow the steps for training. It is a pain at first, but well worth it !
# Generated Assistant: I have a small dog and this has been great. I have a medium sized dog and he can adjust it to his liking.
#
# Metrics:
# BLEU Score: 0.0058
# ROUGE-1: 0.1389
# ROUGE-2: 0.0000
# ROUGE-L: 0.1111
# Cosine Similarity: 0.4899
# --------------------------------------------------------------------------------
#
# Sample 9:
# User: Can you buy separate pieces? I have 3 sets, but only 3 straight pieces. I would like a couple more to make a bigger design.
# Actual Assistant: I do not know about buying separate pieces, but I cannot keep mine together. The ball also continually gets stuck in the track and my cats lose interest. I have four cats so it would have been nice if at least one of them had liked it.
# Generated Assistant: Yes, you can buy the whole set. I have two sets of each. The first set is for the big cat and the second set is for the small cat. I have one set of each for the medium and the other set for the small cat.
#
# Metrics:
# BLEU Score: 0.0400
# ROUGE-1: 0.2553
# ROUGE-2: 0.0217
# ROUGE-L: 0.2128
# Cosine Similarity: 0.5380
# --------------------------------------------------------------------------------
#
# Sample 10:
# User: Does the bag have an attached leash inside the bag to keep the dog from jumping out even when the bag is slightly open?
# Actual Assistant: Yes it does, it is sewn up in one corner. However it is not adjustable to length and my girls could get far enough out to pull the case along for a walk so check that.
# Generated Assistant: Yes, it does have a leash inside.
#
# Metrics:
# BLEU Score: 0.0035
# ROUGE-1: 0.1860
# ROUGE-2: 0.0976
# ROUGE-L: 0.1860
# Cosine Similarity: 0.3824
# --------------------------------------------------------------------------------
#
# Sample 11:
# User: Are these made in the USA?
# Actual Assistant: Yes, made in the USA. I would never feed my dogs anything made in China.
# Generated Assistant: They are made in the USA.
#
# Metrics:
# BLEU Score: 0.1277
# ROUGE-1: 0.3810
# ROUGE-2: 0.3158
# ROUGE-L: 0.3810
# Cosine Similarity: 0.5693
# --------------------------------------------------------------------------------
#
# Sample 12:
# User: Have 4 cats. Building a new house. Everything will be different and "new". Will this help them adjust?
# Actual Assistant: I would say it should. My cats do just fine with it.
# Generated Assistant: I am not sure. I am not sure what to do with the cat's fur. I am sure that the cat will be able to adjust and adjust it.
#
# Metrics:
# BLEU Score: 0.0247
# ROUGE-1: 0.2381
# ROUGE-2: 0.0000
# ROUGE-L: 0.1905
# Cosine Similarity: 0.5562
# --------------------------------------------------------------------------------
#
# Sample 13:
# User: Does this collar offer vibrate as well as shock stimulation? I would like to be able to use vibration before a shock is used.
# Actual Assistant: Hi. The unit we have makes a sound that warns the dog he is doing something wrong. It is a separate button totally. The sound can be increased also. The shock button is totally separate from the sound button and can also be adjusted to a higher # if needed. It has been a HUGE help to us with our Malamute and has helped in her training. Our daughter has a Lab/Newfie mix and they have had excellent results with their collar also. Highly recommend it. Good luck. Sue
# Generated Assistant: I have not tried it, but I think it works well. I have not heard of any vibration before, so I do not know if this collar is for vibrating or not.
#
# Metrics:
# BLEU Score: 0.0025
# ROUGE-1: 0.1322
# ROUGE-2: 0.0000
# ROUGE-L: 0.0826
# Cosine Similarity: 0.3996
# --------------------------------------------------------------------------------
#
# Sample 14:
# User: I have a small 5 gallon tank. Can this filter fit on that size tank?
# Actual Assistant: I do not know about it dimensionally but this is really made for a 10-20 gallon tank. The force of the water flow might be too great for a tank that small. You need to buy a filter sized for your tank and I have never looked for a 5 gallon filter before. I just googled it and got some results but I do not want to suggest something I have not tried.
# Generated Assistant: I would not think so. The size of the filter is very small.
#
# Metrics:
# BLEU Score: 0.0012
# ROUGE-1: 0.2069
# ROUGE-2: 0.0235
# ROUGE-L: 0.1379
# Cosine Similarity: 0.4447
# --------------------------------------------------------------------------------
#
# Sample 15:
# User: Can I use it in one long line to block off my apt patio and keep dogs on patio?
# Actual Assistant: You can if you have something to secure it on each end. We use it as a room divider for large room openings. Since it is not all the way stretched out (we leave some of it sort of like an accordion), it stays standing.
# Generated Assistant: Yes, it is a small plastic enclosure, but it is a very sturdy piece of metal. It is also very sturdy.
#
# Metrics:
# BLEU Score: 0.0148
# ROUGE-1: 0.1818
# ROUGE-2: 0.0313
# ROUGE-L: 0.1818
# Cosine Similarity: 0.2492
# --------------------------------------------------------------------------------
#
# Sample 16:
# User: Would my birds be able to get out if I removed the bottom grate and just keep the tray in as the bottom?
# Actual Assistant: It depends on what kind of bird. I do not think a Cockatiel would be able to get out but a smaller bird might be able to. The grate slides in and out and the tray sits on its own track. For what it is worth, I am really happy with this cage and so is my bird.
# Generated Assistant: No, the tray is very small. You can easily remove the tray by hand but it is a little tricky.
#
# Metrics:
# BLEU Score: 0.0083
# ROUGE-1: 0.2051
# ROUGE-2: 0.0526
# ROUGE-L: 0.1282
# Cosine Similarity: 0.4239
# --------------------------------------------------------------------------------
#
# Sample 17:
# User: do you have to buy the tubes to attach it to the cage
# Actual Assistant: Yes, you need to buy the tubes (tunnels) and 2 elbow tubes (tunnels) for this snap wheel. I recommend that you buy these tubes (tunnels) separate. There is a package of tubes (tunnels) that does connect this wheel and connects to your cage.
# Generated Assistant: Yes, you can buy a tube for $10. The tube is a bit small, so it may be a little difficult to attach it to the cage. I would recommend that you buy a small tube and attach it to the cage.
#
# Metrics:
# BLEU Score: 0.0870
# ROUGE-1: 0.4471
# ROUGE-2: 0.1446
# ROUGE-L: 0.3529
# Cosine Similarity: 0.5397
# --------------------------------------------------------------------------------
#
# Sample 18:
# User: Will it burn out if left empty?
# Actual Assistant: no.... it is a low heat to keep water from freezing....but will merely heat the air...and would not get too hot for the animals tongue on the empty surface..... i have one and do check constantly for filling as there will be evaporation in warmer atmospheres.
# Generated Assistant: I have not had it burn out but I do not think it will, the bottom of the bowl is covered in a layer of plastic that will allow it to dry out.
#
# Metrics:
# BLEU Score: 0.0176
# ROUGE-1: 0.3457
# ROUGE-2: 0.0253
# ROUGE-L: 0.1481
# Cosine Similarity: 0.2034
# --------------------------------------------------------------------------------
#
# Sample 19:
# User: I live in Asia where dog theft is pretty prevalent. I Am looking for a chip that I can use to track down my dog should this happen. Is this what I want?
# Actual Assistant: This is a small rice sized chip you or your vet will need to inject into your dog. You must register it after that. If you do no register this it has no effect if the dog would be found. This can not track your dog down. I am not aware of any chips that have a gps/tracking feature.
# Generated Assistant: I have a dog that is a mix of German and American and it is very hard to get a chip to track him down. It is very easy to get a chip to track down a dog and it works great. I have a good friend who lives in Asia and we have been having a good time. He is very happy and is getting better. I have used a chip that works great and it is working great for him.
#
# Metrics:
# BLEU Score: 0.0199
# ROUGE-1: 0.2535
# ROUGE-2: 0.0429
# ROUGE-L: 0.1408
# Cosine Similarity: 0.6440
# --------------------------------------------------------------------------------
#
# Sample 20:
# User: will this dispense very small amts? my bettas eat only 5-8 micro pellets at a time
# Actual Assistant: It is fully adjustable, I believe that it should be able to dispense the way you want it to. It works for me and I am breeding guppies and this feeder has worked like a charm for me
# Generated Assistant: No, I do not think so. I do not think you can dispense small amts in the small amount. It would not work as well as a large amt.
#
# Metrics:
# BLEU Score: 0.0263
# ROUGE-1: 0.2388
# ROUGE-2: 0.0000
# ROUGE-L: 0.1791
# Cosine Similarity: 0.3591
# --------------------------------------------------------------------------------
#
# Sample 21:
# User: Would this product help my cat with her stress over grooming?
# Actual Assistant: The cat I got it for has bad anger issues, he was abused. This did not do much for him. I would say try one package for your cat's issue.
# Generated Assistant: Yes, it does. It is great for all cats and will help them to relax.
#
# Metrics:
# BLEU Score: 0.0083
# ROUGE-1: 0.1304
# ROUGE-2: 0.0000
# ROUGE-L: 0.1304
# Cosine Similarity: 0.3944
# --------------------------------------------------------------------------------
#
# Sample 22:
# User: Can I use this for gerbils? They tend to chew everything.
# Actual Assistant: Yes. Our rabbit chews and has attempted to chew this. The pad is hard, and a decen length of cord is coated metal. Bunny did manage to chew the coating off but that is it. I might consider putting under the gerbil cage if it is plastics bottomed.
# Generated Assistant: Yes, I have two gerbils. I use it for them and they are fine.
#
# Metrics:
# BLEU Score: 0.0053
# ROUGE-1: 0.1613
# ROUGE-2: 0.0000
# ROUGE-L: 0.1290
# Cosine Similarity: 0.4783
# --------------------------------------------------------------------------------
#
# Sample 23:
# User: Does this cage come with a stand?
# Actual Assistant: No it does not come with a stand but we love the cage.
# Generated Assistant: No, it is not included.
#
# Metrics:
# BLEU Score: 0.0168
# ROUGE-1: 0.3333
# ROUGE-2: 0.1250
# ROUGE-L: 0.3333
# Cosine Similarity: 0.2584
# --------------------------------------------------------------------------------
#
# Sample 24:
# User: is it too high for a labradoe
# Actual Assistant: It should not be. We have two Austrailian Shepherds that use this one. Our Australian cattle dog (Blue Heeler) is about 2 inches shorter than the Aussies so he does not use it much. He prefers to eat/drink from the bowl on the floor. My brother has always had Labs and their usual size is on the 'large dog' side, so his Labs would have no problem using this feeder. Hope this info helps! :)
# Generated Assistant: No, it is very high and it does not seem to be able to handle the pressure. I have tried some other products and it seems to be working fine.
#
# Metrics:
# BLEU Score: 0.0061
# ROUGE-1: 0.2095
# ROUGE-2: 0.0194
# ROUGE-L: 0.1333
# Cosine Similarity: 0.1394
# --------------------------------------------------------------------------------
#
# Sample 25:
# User: Would this stroller be easy to get on and off of a city bus with?
# Actual Assistant: It is very light weight, so that would helpful. The bus driver might say that it is too big, but I do not have experience riding buses so I do not know about that.
# Generated Assistant: I think it would be. I have a small dog who likes to get on and off the bus. It would be hard to get it on and off of it.
#
# Metrics:
# BLEU Score: 0.0243
# ROUGE-1: 0.2462
# ROUGE-2: 0.0317
# ROUGE-L: 0.1538
# Cosine Similarity: 0.5853
# --------------------------------------------------------------------------------
#
# Sample 26:
# User: Will this wireless fence work around an aluminum sided house and pool?
# Actual Assistant: We have siding and a pool and works well....
# Generated Assistant: Yes. It is a very sturdy fence and works great.
#
# Metrics:
# BLEU Score: 0.0528
# ROUGE-1: 0.3158
# ROUGE-2: 0.1176
# ROUGE-L: 0.3158
# Cosine Similarity: 0.3394
# --------------------------------------------------------------------------------
#
# Sample 27:
# User: Is the base detachable? I want to zip-tie the pole to a 48" tall cage to get the necessary elevation, but a non-detachable base would prevent this.
# Actual Assistant: Yes, the base is detachable. The stand comes in three pieces - base, pole, and L-shaped "arm" - so you can use the screws to adjust the height of the stand and the reach of the "arm" over the tank.
# Generated Assistant: I have a 48" tall cage that is 12" tall, and a small cage that is 15" tall. I have two 8" long poles, and they are very sturdy.
#
# Metrics:
# BLEU Score: 0.0178
# ROUGE-1: 0.1176
# ROUGE-2: 0.0303
# ROUGE-L: 0.0882
# Cosine Similarity: 0.1298
# --------------------------------------------------------------------------------
#
# Sample 28:
# User: Do you ever need to change the blade drive? This will replace my switchblade, and I change that blade drive regularly.
# Actual Assistant: You have to send it into Wahl and they do it free of charge.
# Generated Assistant: I do not know if it is possible to change the blade drive.
#
# Metrics:
# BLEU Score: 0.0232
# ROUGE-1: 0.2222
# ROUGE-2: 0.0000
# ROUGE-L: 0.1481
# Cosine Similarity: 0.2609
# --------------------------------------------------------------------------------
#
# Sample 29:
# User: Is this collar good for small dogs? I recently adopted a Maltese mix 3 yr old puppy mill dog.She is very timid, and is afraid of the outsiside.
# Actual Assistant: This type of therapy can help any size dog. Just do not expect a miracle. It can take the edge off their anxiety. You may not know how well it works until the efficacy of the collar starts to fade and you need a new one.
# Generated Assistant: Yes, it is good for small dogs.
#
# Metrics:
# BLEU Score: 0.0003
# ROUGE-1: 0.0755
# ROUGE-2: 0.0000
# ROUGE-L: 0.0377
# Cosine Similarity: 0.4925
# --------------------------------------------------------------------------------
#
# Sample 30:
# User: Is there a way to prevent my dog from backing out of this harness? I do make sure it is tightened securely on his body, but he is gotten out of it.
# Actual Assistant: Brenda, I have to think you have a harness that is too large for your dog. I cannot imagine how it could back out if the size is correct.
# Generated Assistant: I do not think there is a way to prevent the harness from buckling. The harness does not allow the dog to pull up and down and you can easily slip it in.
#
# Metrics:
# BLEU Score: 0.0158
# ROUGE-1: 0.3226
# ROUGE-2: 0.0000
# ROUGE-L: 0.1935
# Cosine Similarity: 0.5236
# --------------------------------------------------------------------------------
#
# Sample 31:
# User: is it on the ground
# Actual Assistant: It sits outside of the aquarium. Whatever your tank is sitting on, a table or stand,etc. It does NOT go in the water. Its a real good strong pump and very quiet.
# Generated Assistant: Yes, it is on the ground.
#
# Metrics:
# BLEU Score: 0.0009
# ROUGE-1: 0.2051
# ROUGE-2: 0.0000
# ROUGE-L: 0.2051
# Cosine Similarity: 0.2934
# --------------------------------------------------------------------------------
#
# Sample 32:
# User: Does this actually have conditioner in it as well? My little old westie will only let me go through one cycle, so I have to use a true combo!
# Actual Assistant: No. And it makes the hair very coarse and dry...to be honest I have not found a whitening shampoo that does not do that to their hair. I have a Bichon and have tried whitening shampoo's that were $30 and did not give good results as far as the texture of the hair. I have given up and just use baby shampoo...i have given up on whiteners
# Generated Assistant: I have not had this problem. I have a little cat who is very fast and has never had any problems.
#
# Metrics:
# BLEU Score: 0.0163
# ROUGE-1: 0.1758
# ROUGE-2: 0.0899
# ROUGE-L: 0.1538
# Cosine Similarity: 0.1267
# --------------------------------------------------------------------------------
#
# Sample 33:
# User: Does this product need to be refrigerated once opened?
# Actual Assistant: I recall it stating on the box that refrigeration was not required because of its special container (but I do anyway, just in case it helps slow the staling).
# Generated Assistant: No, it does not need to be refrigerated.
#
# Metrics:
# BLEU Score: 0.0033
# ROUGE-1: 0.1622
# ROUGE-2: 0.0000
# ROUGE-L: 0.1081
# Cosine Similarity: 0.7048
# --------------------------------------------------------------------------------
#
# Sample 34:
# User: Does a 16 oz. water bottle fit (like from super markets) in the pouches?
# Actual Assistant: I have no trouble fitting a 16 oz bottle either.
# Generated Assistant: I have not tried this but it fits pretty well. I have a small dog and it fits well.
#
# Metrics:
# BLEU Score: 0.0337
# ROUGE-1: 0.2759
# ROUGE-2: 0.0741
# ROUGE-L: 0.2759
# Cosine Similarity: 0.1944
# --------------------------------------------------------------------------------
#
# Sample 35:
# User: Is it possible to just order a replacement arm portion? The bungie attached to the harness clasp broke.
# Actual Assistant: Email the company who makes it. They replaced that part for me and were very, very helpful!
# Generated Assistant: Yes it is possible to order a replacement arm portion. I bought a replacement arm and it is the same size as the original arm.
#
# Metrics:
# BLEU Score: 0.0144
# ROUGE-1: 0.1905
# ROUGE-2: 0.0000
# ROUGE-L: 0.1429
# Cosine Similarity: 0.3953
# --------------------------------------------------------------------------------
#
# Sample 36:
# User: Does the Hydor USA SlimSkim version work with 220V 50Hz?
# Actual Assistant: It needs 110 outlet or 12 v if your hard wiring it to your system. standard USA power. If you your more specific I could help you further..
# Generated Assistant: No, it does not. The Hydor USA SlimSkim version does not work with 220V 50Hz.
#
# Metrics:
# BLEU Score: 0.0098
# ROUGE-1: 0.0930
# ROUGE-2: 0.0000
# ROUGE-L: 0.0930
# Cosine Similarity: 0.2990
# --------------------------------------------------------------------------------
#
# Sample 37:
# User: Can it be used in a volvo xc90 and Audi a5?
# Actual Assistant: Works in my 2007 Volvo xc70, but I cannot speak otherwise.
# Generated Assistant: I have a V8 Audi A5 and this is the only one I have that works. It works great and is very easy to clean.
#
# Metrics:
# BLEU Score: 0.0134
# ROUGE-1: 0.1111
# ROUGE-2: 0.0000
# ROUGE-L: 0.0556
# Cosine Similarity: 0.2392
# --------------------------------------------------------------------------------
#
# Sample 38:
# User: is it really unscented? returned Grizzly wild salmon oil due to strong fishy odor
# Actual Assistant: IT IS INDEED. MY 5 DOGS LOVE IT AND NO FISHY ODOR. MUCH SUPERIOR TO ANY OF THE "SO-Called" salmon oils I tried before. Been using this for a couple of years. Time for me to re-order
# Generated Assistant: It is not unscented. It smells like a strong odor. It is very well formulated and the odor is not overpowering.
#
# Metrics:
# BLEU Score: 0.0202
# ROUGE-1: 0.2333
# ROUGE-2: 0.0345
# ROUGE-L: 0.1667
# Cosine Similarity: 0.3671
# --------------------------------------------------------------------------------
#
# Sample 39:
# User: Have a total of 7 cats! I am concerned about it getting toppled over. Is there a way to fasten down to wall or ceiling?
# Actual Assistant: I have 3 cats running up and down it all the time and there is not problem. It is very stable. I do have 1 side of it sitting up against the wall. You could get a couple of straps from the home improvement store and wrap them around the upper posts then attach to the wall. I do not think you will have a problem. It is well made and very stable.
# Generated Assistant: I have a total of 7 cats. I do not know if there is a way to fasten down to wall or ceiling but I have used the "L" type of fastener on a cat to prevent the cat from getting stuck in it.
#
# Metrics:
# BLEU Score: 0.0460
# ROUGE-1: 0.3761
# ROUGE-2: 0.0870
# ROUGE-L: 0.2051
# Cosine Similarity: 0.5908
# --------------------------------------------------------------------------------
#
# Sample 40:
# User: Does this design come in any other colors besides this tangerine-looking color??
# Actual Assistant: Sorry, this is the only color for this specific one. We do have others in different colors, but not this specific one.
# Generated Assistant: I do not know if it is a color or a design. I would say it is a great design.
#
# Metrics:
# BLEU Score: 0.0157
# ROUGE-1: 0.1905
# ROUGE-2: 0.0000
# ROUGE-L: 0.0952
# Cosine Similarity: 0.3795
# --------------------------------------------------------------------------------
#
# Sample 41:
# User: Will a regular tank with a black light have the same effect as these fancy led blue bulbs?
# Actual Assistant: It would probably be a little different. These are just blue led lights....
# Generated Assistant: I would say yes, but not sure about the color. I would also say that if you are using the LED bulb you will need to adjust the brightness level to get the best results.
#
# Metrics:
# BLEU Score: 0.0108
# ROUGE-1: 0.1250
# ROUGE-2: 0.0000
# ROUGE-L: 0.1250
# Cosine Similarity: 0.6159
# --------------------------------------------------------------------------------
#
# Sample 42:
# User: Is there a size chart for this product?? I cannot find one anywhere
# Actual Assistant: Unless you have an itty-bitty kitty (7lbs and under), you will do fine with the medium/large. My cat Bhodi is about 12 to 14lbs, and the medium/large works great. There is lots of adjustable room with the velcro straps at the neck and the belly, so you should be fine. Be prepared for your cat not loving the harness at first (Bhodi just flopped over and would only walk backwards at first!) Good luck!
# Generated Assistant: There is a small one at the bottom of the page. I have not used this product in my dog's litter box, but I do not think it would be a good fit for a large dog.
#
# Metrics:
# BLEU Score: 0.0105
# ROUGE-1: 0.2609
# ROUGE-2: 0.0354
# ROUGE-L: 0.1391
# Cosine Similarity: 0.3173
# --------------------------------------------------------------------------------
#
# Sample 43:
# User: Does the "One level" still include 2 replacement pieces?
# Actual Assistant: Yes. That is what I ordered - it ends up being like $10 with tax - but there are 2 pieces with 2 usable sides each.
# Generated Assistant: I think it does. I think you can buy a single replacement piece, but I would suggest buying a single replacement piece. I also think you can buy a two level piece.
#
# Metrics:
# BLEU Score: 0.0119
# ROUGE-1: 0.1429
# ROUGE-2: 0.0000
# ROUGE-L: 0.1429
# Cosine Similarity: 0.4665
# --------------------------------------------------------------------------------
#
# Sample 44:
# User: Has the problem of the lid opening during shipping been fixed yet? I have he would this problem and want to order but want all I pay for.
# Actual Assistant: I did not experience that problem. I received the bottle intact and because it is a tall bottle I deposited a portion of it in a smaller, easier to handle container and store the original bottle until needed.
# Generated Assistant: I have no problem with the lid opening. I have had the lid open for about a week and have not had any problems. I do not think the problem is fixed. I have tried it with the padlock and the lid has opened. It has not opened up. I would buy again.
#
# Metrics:
# BLEU Score: 0.0184
# ROUGE-1: 0.2857
# ROUGE-2: 0.0225
# ROUGE-L: 0.2198
# Cosine Similarity: 0.3799
# --------------------------------------------------------------------------------
#
# Sample 45:
# User: is it good for a ferret
# Actual Assistant: This cage is big...I think it is a little too big for a ferret. .. this cage fit my 2 labs and a zhitpoo...
# Generated Assistant: I do not think it will work for a ferret. I have a ferret and she has a very small nose and a very large nose. I have a dog and he has to get out of the house to get to the house. It works for her and it works for her.
#
# Metrics:
# BLEU Score: 0.0570
# ROUGE-1: 0.2338
# ROUGE-2: 0.1067
# ROUGE-L: 0.2078
# Cosine Similarity: 0.7825
# --------------------------------------------------------------------------------
#
# Sample 46:
# User: Hello, I have a small 5 to 6 lb Maltese. Will this collar fit him? Thank you
# Actual Assistant: This is the best collar out there but it probably would be too big for a 6 lb dog. If you do purchase it you will be able to get it on and use it. But you will not like the size of it. Another good thing is if used properly you will not have to use it much. It will help to break bad habits. I have a Minny Pinscher 15lbs he can handle it just barely.
# Generated Assistant: I have a medium sized dog. He is 5'2" and he is comfortable.
#
# Metrics:
# BLEU Score: 0.0027
# ROUGE-1: 0.1957
# ROUGE-2: 0.0444
# ROUGE-L: 0.0870
# Cosine Similarity: 0.3396
# --------------------------------------------------------------------------------
#
# Sample 47:
# User: Is this particular model adjustable?
# Actual Assistant: Yes, it has quite a lot of adjustment
# Generated Assistant: I have a cat that is about 5 pounds and it would fit the cat in it.
#
# Metrics:
# BLEU Score: 0.0169
# ROUGE-1: 0.1600
# ROUGE-2: 0.0000
# ROUGE-L: 0.0800
# Cosine Similarity: -0.1213
# --------------------------------------------------------------------------------
#
# Sample 48:
# User: can this be used with a puppy?
# Actual Assistant: Depends on the puppy. Yorkie, probably not. We used it on our mixed breed pup starting at about 16 weeks old (she is now 55 lbs.) to safely run around and it was fine. Being klutzy and crazy at that age she sometimes got it tangled up. it is LOOOOOOOOOOOOONG and strong!
# Generated Assistant: Yes it can, it is made of a plastic material and is very durable. It is not a dog bed and it does not have a side door. It is very comfortable to sleep in.
#
# Metrics:
# BLEU Score: 0.0301
# ROUGE-1: 0.2299
# ROUGE-2: 0.0471
# ROUGE-L: 0.1839
# Cosine Similarity: 0.3324
# --------------------------------------------------------------------------------
#
# Sample 49:
# User: My bichon frise matts. Will this help?
# Actual Assistant: That is a big "yes" follow the directions exactly. Really a great company to do business with.
# Generated Assistant: Yes it will. It is very sturdy and sturdy enough for my dog to use. I have a 15 pound German Shepherd, who is very small and I use it for her at home.
#
# Metrics:
# BLEU Score: 0.0119
# ROUGE-1: 0.1569
# ROUGE-2: 0.0000
# ROUGE-L: 0.0784
# Cosine Similarity: 0.0091
# --------------------------------------------------------------------------------
#
# Sample 50:
# User: Hi,could 2 chihuahuas fit in the small size? Thanks
# Actual Assistant: Yes it could.... only one harness strap though.... if you sew, you probably could add another.
# Generated Assistant: I am sure the chihuahuas would fit in the larger size.
#
# Metrics:
# BLEU Score: 0.0103
# ROUGE-1: 0.0000
# ROUGE-2: 0.0000
# ROUGE-L: 0.0000
# Cosine Similarity: 0.2537
# --------------------------------------------------------------------------------
#
# Sample 51:
# User: will it fit a full grown german shepard?
# Actual Assistant: I would get the X-large one just to make sure there is plenty of room. But, yes, it will fit a full grown German Shepard. We have been very happy w/ ours. It is durable and weather-resistant. (it has been in way below zero weather up to 100 + degrees weather)
# Generated Assistant: I would not think so. I have not tried it.
#
# Metrics:
# BLEU Score: 0.0013
# ROUGE-1: 0.1290
# ROUGE-2: 0.0333
# ROUGE-L: 0.1290
# Cosine Similarity: -0.1624
# --------------------------------------------------------------------------------
#
# Sample 52:
# User: does this lamp have a replaceable ballast that you can change in the event that it goes bad?
# Actual Assistant: I think just the light bulb is replaceable.
# Generated Assistant: It does not. It is a plastic ballast that you can change in the event that it goes bad.
#
# Metrics:
# BLEU Score: 0.0165
# ROUGE-1: 0.1481
# ROUGE-2: 0.0000
# ROUGE-L: 0.0741
# Cosine Similarity: 0.2324
# --------------------------------------------------------------------------------
#
# Sample 53:
# User: does it come with the plastic bar for the screws to go in
# Actual Assistant: Yes, three screws across the top.
# Generated Assistant: Yes it does come with the plastic bar for the screws to go in.
#
# Metrics:
# BLEU Score: 0.0235
# ROUGE-1: 0.3000
# ROUGE-2: 0.0000
# ROUGE-L: 0.2000
# Cosine Similarity: 0.4306
# --------------------------------------------------------------------------------
#
# Sample 54:
# User: Could you use this bike leash while having a trail-a-bike attachment for a young child?
# Actual Assistant: Yes. The bike tow leash attaches to the back tire frame on the left side. The trail-a-bike looks like it attaches under your seat. Your dog will run along the left side of you while your child is behind you.
# Generated Assistant: I do not know if it is possible to attach the leash to the bike but it would be nice to have some sort of attachment. I have a small dog and it is not a great fit for him. I would not recommend this.
#
# Metrics:
# BLEU Score: 0.0249
# ROUGE-1: 0.2759
# ROUGE-2: 0.0471
# ROUGE-L: 0.2069
# Cosine Similarity: 0.7178
# --------------------------------------------------------------------------------
#
# Sample 55:
# User: will pet safe wireless fence work if the house has a tin roof
# Actual Assistant: I really do not know the answer to that question. I assumed the transmissions were picked up via window openings because the inside unit had to sit at a certain distance from the floor. I love the unit - my little guy can run freely without fear of harm to him.
# Generated Assistant: Yes, the fence is very strong. It will not hold a dog at all.
#
# Metrics:
# BLEU Score: 0.0027
# ROUGE-1: 0.1250
# ROUGE-2: 0.0000
# ROUGE-L: 0.0625
# Cosine Similarity: -0.0006
# --------------------------------------------------------------------------------
#
# Sample 56:
# User: Is the case made of glass?
# Actual Assistant: Yes Nancy it is made of glass with a mesh top that slides in and out.
# Generated Assistant: No, the case is made of glass.
#
# Metrics:
# BLEU Score: 0.1297
# ROUGE-1: 0.3478
# ROUGE-2: 0.2857
# ROUGE-L: 0.3478
# Cosine Similarity: 0.6524
# --------------------------------------------------------------------------------
#
# Sample 57:
# User: do i have a bad batch? all my food looks the same, purple mush. first time ordered, so i do not know what to expect. it says whole, but each can is mush
# Actual Assistant: The "sardine cutlets" should have whole fish in them surrounded by some jelly/mush. Some of the other "pate" varieties are all mush.
# Generated Assistant: I do not think so. I have used the same brand of product for the last 3 years. I have used the same brand for the last 2 years and the same product for the last 2 years. I have not had any problems with this product. I have had it for 3 years now and I have used it for about 10 years now. I do not think it is a good product. I do not think it is a good product.
#
# Metrics:
# BLEU Score: 0.0058
# ROUGE-1: 0.0755
# ROUGE-2: 0.0000
# ROUGE-L: 0.0566
# Cosine Similarity: 0.0386
# --------------------------------------------------------------------------------
#
# Sample 58:
# User: Is it effective for bad breath?
# Actual Assistant: We do not feed the dog that uses this toothpaste fish in any form, but his breath smells fishy. I cannot say it is the toothpaste, but the toothpaste is not doing anything about it, either.
# Generated Assistant: Yes, it is very effective for bad breath. I have used it on my dog and he has never had a bad breath. I do not think it works for him but it does work for me.
#
# Metrics:
# BLEU Score: 0.0310
# ROUGE-1: 0.2740
# ROUGE-2: 0.0563
# ROUGE-L: 0.1644
# Cosine Similarity: 0.4426
# --------------------------------------------------------------------------------
#
# Sample 59:
# User: I am interested in your collar, but the photos do not show a hook for a leash. Does the collar have one?
# Actual Assistant: Yes, there is a bail to attach a leash
# Generated Assistant: I do not think so. I think the collar is just a wire.
#
# Metrics:
# BLEU Score: 0.0197
# ROUGE-1: 0.1818
# ROUGE-2: 0.0000
# ROUGE-L: 0.1818
# Cosine Similarity: 0.4571
# --------------------------------------------------------------------------------
#
# Sample 60:
# User: Is the top openable; meaning is there a zipper or something that opens up the mesh top?
# Actual Assistant: Yes. There is a zipper to enclose the pet. There is also a flap to put the animal in along the side of the item.
# Generated Assistant: I would not say yes, it is not openable.
#
# Metrics:
# BLEU Score: 0.0061
# ROUGE-1: 0.1176
# ROUGE-2: 0.0000
# ROUGE-L: 0.1176
# Cosine Similarity: 0.2849
# --------------------------------------------------------------------------------
#
# Sample 61:
# User: Is this trimmer quiet? It is for a 7 lb. Yorkie.
# Actual Assistant: Yes, it is super quiet and efficient. I have 8 pound long haired Chihuahuas. They are the best trimmers I have ever purchased. And i have tried A LOT. I hope this helps you.
# Generated Assistant: I am not sure, but I would say it is quieter than the other trimmer.
#
# Metrics:
# BLEU Score: 0.0122
# ROUGE-1: 0.2449
# ROUGE-2: 0.0426
# ROUGE-L: 0.1633
# Cosine Similarity: 0.5219
# --------------------------------------------------------------------------------
#
# Sample 62:
# User: I do not use a carbon filter just a hydro sponge for a 2.5g. Am I ok to just do a partial water change after the treatment and rinse out the filter??
# Actual Assistant: Hey Tony, Yes that would be perfect. I have similar setups in my 2.5's and do the same. Just be sure to break the tab in 1/4's for that size tank. Jon
# Generated Assistant: I have been using a carbon filter for about a month now. It does not have a filter that is as big as the one I have, but it is a great filter. I do not have a problem with the filter not being able to filter out the water, but I have had problems with the filter not being able to filter out the water. I have also had issues with the filter not being able to filter out the water. I do not know what the problem is with the water, but it does seem to be getting worse.
#
# Metrics:
# BLEU Score: 0.0174
# ROUGE-1: 0.1460
# ROUGE-2: 0.0148
# ROUGE-L: 0.1168
# Cosine Similarity: 0.0637
# --------------------------------------------------------------------------------
#
# Sample 63:
# User: So the gel lubricant for these clippers. Can I buy it somewhere. My dog ate the bottle before I could use it.
# Actual Assistant: Give Wahl a call or contact then via email Satisfaction@Wahlclipper.com.
# Generated Assistant: I have used this gel for a year and it is a good lubricant. I would recommend it.
#
# Metrics:
# BLEU Score: 0.0155
# ROUGE-1: 0.0667
# ROUGE-2: 0.0000
# ROUGE-L: 0.0667
# Cosine Similarity: 0.1243
# --------------------------------------------------------------------------------
#
# Sample 64:
# User: Is this standard size for an English pointer
# Actual Assistant: I am not sure how big an English Pointer is but I use this table for my Chow "Hope". She weighs about 55 pounds and the table is sturdy and stable. The truth is I am about to give her a bath today. Usually I dry her in the garage but today I have set the table up in the driveway so she can be out and the breeze will help keep her cool until I get her dry which is about a 2 hour chore. lol That would be a chore of love!!!! Jerry in Indiana
# Generated Assistant: Yes it is for a French pointer.
#
# Metrics:
# BLEU Score: 0.0000
# ROUGE-1: 0.0769
# ROUGE-2: 0.0000
# ROUGE-L: 0.0577
# Cosine Similarity: 0.3956
# --------------------------------------------------------------------------------
#
# Sample 65:
# User: Will this work on dry fur?
# Actual Assistant: Yes, I prefer to put it on dry fur. Then, when it dries, you will see how effective it is when you comb it out.
# Generated Assistant: I have been using it for a few years now and I have not had a problem. I have a 5 year old Labrador that has a furball and I have never had a problem.
#
# Metrics:
# BLEU Score: 0.0110
# ROUGE-1: 0.0667
# ROUGE-2: 0.0000
# ROUGE-L: 0.0667
# Cosine Similarity: 0.3416
# --------------------------------------------------------------------------------
#
# Sample 66:
# User: Are Oster Classic 76 blades interchangeable with A5 blades? Thinking replacing my broke 76 with stronger A5 (know it is for pets - do not judge!)
# Actual Assistant: Sorry, but I do not know.
# Generated Assistant: No, the blades are interchangeable. If you have a dog that is a medium sized dog or a medium sized dog that is a medium sized dog, you might need to replace the blades.
#
# Metrics:
# BLEU Score: 0.0091
# ROUGE-1: 0.0000
# ROUGE-2: 0.0000
# ROUGE-L: 0.0000
# Cosine Similarity: 0.0662
# --------------------------------------------------------------------------------
#
# Sample 67:
# User: Can I use this on my lawn to remove the odor?
# Actual Assistant: The suggested use is for carpet and indoors. Never thought to try the pricy stuff outdoors. I would go to a garden center and ask for some deterrent made specially for that problem.
# Generated Assistant: Yes, it can.
#
# Metrics:
# BLEU Score: 0.0001
# ROUGE-1: 0.0000
# ROUGE-2: 0.0000
# ROUGE-L: 0.0000
# Cosine Similarity: 0.0222
# --------------------------------------------------------------------------------
#
# Sample 68:
# User: Can this be frozen if it is not all used right away? I foster kittens and hope it will last between litters.
# Actual Assistant: I would not recommend it. You could close the jar tightly and rap it in plastic as air tight as you can and keep it in the fridge. I had to start buying smaller jars or the syringes with the gel. I used this powder every day for 6 weeks on my critters and thought it lost some potency after 4 weeks from the twice a day opening. I have had better success with the gel (15gm syringe) which is cheaper in bulk. But you can call PetAg the maker of Bene-Bac's Customer Service: 1-800-323-6878 or for email go to: [URL] All the best to you and your little fosters.
# Generated Assistant: Yes it can be frozen.
#
# Metrics:
# BLEU Score: 0.0000
# ROUGE-1: 0.0333
# ROUGE-2: 0.0000
# ROUGE-L: 0.0333
# Cosine Similarity: 0.2699
# --------------------------------------------------------------------------------
#
# Sample 69:
# User: Will it work on a puppy? 5 month old german shepherd
# Actual Assistant: The collar does work. As far as size goes go to Cesar's way site:[URL] Go to shop, Leashes and collars. Click "The Illusion Dog Collar & Leash System (Next Generation)" and use the size chart. Hope this helps!
# Generated Assistant: I am not sure, but I think it would be fine for a puppy. It does not need to be a harness and it does not need a leash. I have a German shepherd and he is very active and is very good at it. It works great on him.
#
# Metrics:
# BLEU Score: 0.0097
# ROUGE-1: 0.1348
# ROUGE-2: 0.0000
# ROUGE-L: 0.1124
# Cosine Similarity: 0.4101
# --------------------------------------------------------------------------------
#
# Sample 70:
# User: Does the inside of the bag have a attachable tether to attach to a dog/cat harness ?
# Actual Assistant: It does not, that is the one thing it is missing that I wish it had.
# Generated Assistant: No, the bag has a separate tether. It is a small piece of plastic and holds a dog/cat harness.
#
# Metrics:
# BLEU Score: 0.0342
# ROUGE-1: 0.1667
# ROUGE-2: 0.0588
# ROUGE-L: 0.1667
# Cosine Similarity: 0.1559
# --------------------------------------------------------------------------------
#
# Sample 71:
# User: is it easy to clean?
# Actual Assistant: The opening is big enough to get inside with a scooper. OR there are four clips holding the top on that unclips easily. This IS the biggest litter box that i have found for my BIG tom cat , i would give it 5*****
# Generated Assistant: Yes, I used it in a plastic bag and it was very easy to clean. I also used it on a plastic bag to remove debris from the floor.
#
# Metrics:
# BLEU Score: 0.0160
# ROUGE-1: 0.1944
# ROUGE-2: 0.0000
# ROUGE-L: 0.0833
# Cosine Similarity: 0.2516
# --------------------------------------------------------------------------------
#
# Sample 72:
# User: Will this be a good brush for a sheltie?
# Actual Assistant: This is a great brush for a sheltie or ANY dog with longer hair. I love this comb!!
# Generated Assistant: I do not know what the brush is for but it is a good one. It is easy to use. I do not think it will be a problem for a sheltie.
#
# Metrics:
# BLEU Score: 0.0549
# ROUGE-1: 0.2800
# ROUGE-2: 0.1250
# ROUGE-L: 0.2000
# Cosine Similarity: 0.7307
# --------------------------------------------------------------------------------
#
# Sample 73:
# User: Do these fit exactly/snuggly in the Large Kong size? I am trying to understand the benefit versus a regular ice cube tray.
# Actual Assistant: This kong ice tray makes the treats eaiser for both my dogs to crunch on. It makes the treats not as dense as a regular ice tray. I made the treats in both the kong tray is the way to go .
# Generated Assistant: Yes they do! It is very easy to clean and the size is perfect for my small kong.
#
# Metrics:
# BLEU Score: 0.0066
# ROUGE-1: 0.2373
# ROUGE-2: 0.0000
# ROUGE-L: 0.1356
# Cosine Similarity: 0.3098
# --------------------------------------------------------------------------------
#
# Sample 74:
# User: Are these containers BPA free?
# Actual Assistant: Yes, they are BPA free. I contacted the Van Ness company. Their response "Yes, our pet food containers and bowls and litter boxes (all of our products) are BPA Free and USFDA pet food contact approved."
# Generated Assistant: I have not tested these and it is not BPA free. They are made from a mix of corn, soy, and other ingredients.
#
# Metrics:
# BLEU Score: 0.0374
# ROUGE-1: 0.2712
# ROUGE-2: 0.0702
# ROUGE-L: 0.1695
# Cosine Similarity: 0.6374
# --------------------------------------------------------------------------------
#
# Sample 75:
# User: is this easy enough to punch into a storm door?
# Actual Assistant: Yes, you would need to cut your storm door, and then run bolts thru the perimeter of the pet door as indicated in my first answer. Should be strong enough though...
# Generated Assistant: I have a large cat and it is a very easy to punch through the door. It is made of stainless steel and it does not take a lot of effort to get it to open. It is easy to clean and it is very easy to clean. It has a small hole in the bottom of the door that you can remove and it does not take a lot of effort to get it to open.
#
# Metrics:
# BLEU Score: 0.0125
# ROUGE-1: 0.1667
# ROUGE-2: 0.0189
# ROUGE-L: 0.1296
# Cosine Similarity: 0.3942
# --------------------------------------------------------------------------------
#
# Sample 76:
# User: Would this last for a German Shepherd? She destroys all "indestructible" toys in 5 minutes or less. The only thing that lasts is a Kong solid ball.
# Actual Assistant: I have a 15 pound Pappy and he has been know to destroy everything. Except this Chuckit! I would suggest getting the larger one though and only using as a supervised exercise event.
# Generated Assistant: I have not used it, but it does last for a short time. I have used it for a few years now and it has worked out fine. It is a good product and it works well for a German Shepherd.
#
# Metrics:
# BLEU Score: 0.0212
# ROUGE-1: 0.2432
# ROUGE-2: 0.0278
# ROUGE-L: 0.1892
# Cosine Similarity: 0.2629
# --------------------------------------------------------------------------------
#
# Sample 77:
# User: do the bag rolls from other venders fit inside??
# Actual Assistant: So far yes. We had just bought some from PetSmart and they fit fine. A little snug, but I think there are more bags on the roll, I think all the bags are the same in height. Have had no trouble in that area. Have yet to use the bags I bought with the dispenser, but we are getting close.
# Generated Assistant: I have one that fits in my pocket. It is small, but fits in my bag.
#
# Metrics:
# BLEU Score: 0.0034
# ROUGE-1: 0.2105
# ROUGE-2: 0.0000
# ROUGE-L: 0.1053
# Cosine Similarity: 0.1698
# --------------------------------------------------------------------------------
#
# Sample 78:
# User: Does this fit in a standard water bottle holder on a bicycle?
# Actual Assistant: It should fit I would guess though I have not tried it.
# Generated Assistant: I do not think so. I have a water bottle holder on my bike that fits into a standard bottle holder. I have a small water bottle holder on my bike that fits into a standard bottle holder.
#
# Metrics:
# BLEU Score: 0.0194
# ROUGE-1: 0.2000
# ROUGE-2: 0.0417
# ROUGE-L: 0.1200
# Cosine Similarity: 0.3447
# --------------------------------------------------------------------------------
#
# Sample 79:
# User: This came fitted in the koi pond when I bought my house. I do not know if it needs filter or UV bulb replacement. Is there an indicator for these?
# Actual Assistant: There is a small clear lens on the top. Look at it very closely with your hands eliminating as much light as possible. If it is not shining, the bulb is out. As for the filter, there is an indicator for that too. Go to the Laguna site and it has all of that information and instructions on how to change the light. It is important to it is done correctly.
# Generated Assistant: I do not know if it needs filter or UV bulb replacement.
#
# Metrics:
# BLEU Score: 0.0004
# ROUGE-1: 0.1205
# ROUGE-2: 0.0247
# ROUGE-L: 0.0723
# Cosine Similarity: 0.5054
# --------------------------------------------------------------------------------
#
# Sample 80:
# User: Can I use my glass outflow pipe, instead of the plastic one that comes with this unit?
# Actual Assistant: No idea. I would think so as long as it is the same outside diameter
# Generated Assistant: I have a 12 gallon tank and it is very easy to install.
#
# Metrics:
# BLEU Score: 0.0425
# ROUGE-1: 0.2143
# ROUGE-2: 0.0769
# ROUGE-L: 0.2143
# Cosine Similarity: 0.0112
# --------------------------------------------------------------------------------
#
# Sample 81:
# User: will this small litter box fit a lionhead rabbit?
# Actual Assistant: I have a small rabbit that barely fits this, and a slightly larger rabbit that it does not fit at all. I would go with a larger model if I were you. Personally I use a cat litter box called the lift n sift because it can hold hay while catching poop and pee and is very easy to clean. My buns had a habit of peeing on the floor next to their food.
# Generated Assistant: No, this is a large litter box. It is a small box and does not fit a lionhead rabbit. It is not the best litter box for your rabbit. If you have a dog, you could use a larger litter box for your dog.
#
# Metrics:
# BLEU Score: 0.0345
# ROUGE-1: 0.4068
# ROUGE-2: 0.1207
# ROUGE-L: 0.2203
# Cosine Similarity: 0.5661
# --------------------------------------------------------------------------------
#
# Sample 82:
# User: Is this gluten free?
# Actual Assistant: Yes it is and contains no GMO's either.
# Generated Assistant: No, this is gluten free.
#
# Metrics:
# BLEU Score: 0.0277
# ROUGE-1: 0.2857
# ROUGE-2: 0.0000
# ROUGE-L: 0.1429
# Cosine Similarity: 0.5267
# --------------------------------------------------------------------------------
#
# Sample 83:
# User: will a 20lb miniature schnauzer fit in the small crate?
# Actual Assistant: We bought this for our 13lbs Himalayan cat and it is perfect for him. I would say go up a size for your dog. Best carrier ever though! We love it!
# Generated Assistant: Yes, it would fit perfectly. I had a 20lb schnauzer and it was fine.
#
# Metrics:
# BLEU Score: 0.0201
# ROUGE-1: 0.2667
# ROUGE-2: 0.0465
# ROUGE-L: 0.1778
# Cosine Similarity: 0.4589
# --------------------------------------------------------------------------------
#
# Sample 84:
# User: Can the crate be folded up?
# Actual Assistant: It can be taken apart and lies flat, but it is not something that I would do everyday, but for travel/storage/cleaning it does come apart.
# Generated Assistant: I think so. It is a great crate and I would recommend it for someone who needs to have a crate around their house.
#
# Metrics:
# BLEU Score: 0.0363
# ROUGE-1: 0.2745
# ROUGE-2: 0.0816
# ROUGE-L: 0.1961
# Cosine Similarity: 0.2020
# --------------------------------------------------------------------------------
#
# Sample 85:
# User: Can the Thermo Perch be used for a Canary
# Actual Assistant: well, not sure, but i can tell you, it ranges in temp (near base is more warm) and kiwi (conure) almost seems too big for it...may be too big for a canary...
# Generated Assistant: I have a cat who is 5'8 and weighs 200 lbs. He is very well fed and has a very good appetite. I use the Thermo Perch as a cat litter box and keep him on his side when he is not in it.
#
# Metrics:
# BLEU Score: 0.0104
# ROUGE-1: 0.2051
# ROUGE-2: 0.0000
# ROUGE-L: 0.1026
# Cosine Similarity: 0.3648
# --------------------------------------------------------------------------------
#
# Sample 86:
# User: Does this bed plug in
# Actual Assistant: This is a foam bed not an inflatable air bed.
# Generated Assistant: Yes it does, I use it for my dogs to sleep in and on. It does not have the same "gut" as the bed plug, but it is a good product.
#
# Metrics:
# BLEU Score: 0.0213
# ROUGE-1: 0.1951
# ROUGE-2: 0.0513
# ROUGE-L: 0.0976
# Cosine Similarity: 0.2692
# --------------------------------------------------------------------------------
#
# Sample 87:
# User: Could this double as an auto waterer. not just for food?
# Actual Assistant: I do not think it could double for a auto waterer. It will just run out. It does not have the reservoir mechanism that the auto waterers have.
# Generated Assistant: Yes. You could use it to give your dog a nice ride, but I would not recommend it.
#
# Metrics:
# BLEU Score: 0.0131
# ROUGE-1: 0.2609
# ROUGE-2: 0.0000
# ROUGE-L: 0.1304
# Cosine Similarity: 0.0682
# --------------------------------------------------------------------------------
#
# Sample 88:
# User: Is oratine approved by the vohc?
# Actual Assistant: No, it is not. There is a similar product that is approved.
# Generated Assistant: Yes, it is. I have used it for a few years and the results are amazing. I use it on my dogs, and they love it.
#
# Metrics:
# BLEU Score: 0.0483
# ROUGE-1: 0.1579
# ROUGE-2: 0.0556
# ROUGE-L: 0.1579
# Cosine Similarity: 0.7404
# --------------------------------------------------------------------------------
#
# Sample 89:
# User: Is it safe to leave your fish tank open while using this product?
# Actual Assistant: Look up the kinds of fish you have in the tank. Some fish naturally like to jump out of water, but most do not unless they are made to by something else in the tank. If you are using this while you are going away for awhile and you are worried about a fish jumping, just put a piece of cardboard over the open part of the tank without blocking the feeder. Personally I had a small hole in the top of my hood and I placed the feeder right over the hole and it would drop right into the tank. 9 times out of 10 I would say you would be fine to leave the tank open with the feeder.
# Generated Assistant: I am not sure if it is safe to leave it open while using this product. The product does not work on fish that are not in the tank. I have never had it open on fish that are in the tank.
#
# Metrics:
# BLEU Score: 0.0237
# ROUGE-1: 0.3067
# ROUGE-2: 0.0745
# ROUGE-L: 0.1472
# Cosine Similarity: 0.6529
# --------------------------------------------------------------------------------
#
# Sample 90:
# User: If the dog has an "accident" in the crate, will it leak out the bottom onto the floor? Also how can you clean it after an "accident"
# Actual Assistant: Never had that happen but I do not think it will leak, the floor looks like a sturdy canvas material that you can wipe down. However I always fold a couple puppy training pads and put it on the bottom of the carrier just in case.
# Generated Assistant: No, it does not leak out the bottom. The bottom is clean and the dog is fine.
#
# Metrics:
# BLEU Score: 0.0106
# ROUGE-1: 0.2540
# ROUGE-2: 0.0328
# ROUGE-L: 0.1905
# Cosine Similarity: 0.6859
# --------------------------------------------------------------------------------
#
# Sample 91:
# User: Does wet litter stick to sides?
# Actual Assistant: No not at all....it is very glossy....the only thing that stays on the sides is if they miss the litter and go directly on the side surface but disinfectant wipes have done the trick to clean for me.
# Generated Assistant: I have never used a litter stick to keep my dog from chewing on it. I have a dog that is 5 months old and has been using it daily for about 2 weeks. I think it will be a good idea to have a litter stick to keep her out of it.
#
# Metrics:
# BLEU Score: 0.0098
# ROUGE-1: 0.1935
# ROUGE-2: 0.0000
# ROUGE-L: 0.1290
# Cosine Similarity: 0.4031
# --------------------------------------------------------------------------------
#
# Sample 92:
# User: Is this tool effective on Australian Shepherds?
# Actual Assistant: I would think so. I use the slicker brush in conjunction with the FURminator. My border collie seems to enjoy the slicker brush more though. She will lay down and let me brush her.
# Generated Assistant: Yes, it works perfectly on Australian Shepherds. I have used it for the past 5 years and have never had any problems. It works well for all Australian Shepherds.
#
# Metrics:
# BLEU Score: 0.0212
# ROUGE-1: 0.1270
# ROUGE-2: 0.0000
# ROUGE-L: 0.1270
# Cosine Similarity: 0.4099
# --------------------------------------------------------------------------------
#
# Sample 93:
# User: can this work on a 28g nano cube?
# Actual Assistant: If I am not mistaken it is 29 gallons right? In any event, yes. It will work.
# Generated Assistant: I am not sure. I have a 25g nano cube, but it has a small hole in it, and it does not seem to work well. I am using the same mini-chip that I used in the lab, and it is working fine.
#
# Metrics:
# BLEU Score: 0.0399
# ROUGE-1: 0.2623
# ROUGE-2: 0.1017
# ROUGE-L: 0.2295
# Cosine Similarity: 0.2208
# --------------------------------------------------------------------------------
#
# Sample 94:
# User: would these work well on a medium-long haired st bernard mix?
# Actual Assistant: I do not see why not, as long as you start with the longer guides and keep it oiled. I use mine on my Maltipoo and 3-4 years later it still works great. &#128522;
# Generated Assistant: I have two dogs and they both have medium-long hair. The longer one is a little thicker and the longer one is a bit thicker.
#
# Metrics:
# BLEU Score: 0.0190
# ROUGE-1: 0.1967
# ROUGE-2: 0.0339
# ROUGE-L: 0.1639
# Cosine Similarity: 0.0700
# --------------------------------------------------------------------------------
#
# Sample 95:
# User: can i put a small turle in this tank
# Actual Assistant: This product was a "topper" that attached to the top of a standard tank. As far as the size of the tank it would fit on...yes, I would say it would be fine for a small turtle.
# Generated Assistant: Yes. I have a small tank and it fits my small one.
#
# Metrics:
# BLEU Score: 0.0068
# ROUGE-1: 0.2800
# ROUGE-2: 0.0833
# ROUGE-L: 0.2000
# Cosine Similarity: 0.5550
# --------------------------------------------------------------------------------
#
# Sample 96:
# User: I have a Ford F150. Is this long enough to cover the entire back seat?
# Actual Assistant: I have a 2006 tundra 4door and it is long enough.
# Generated Assistant: I have a Ford F150 that is 8" tall and it fits snugly.
#
# Metrics:
# BLEU Score: 0.1148
# ROUGE-1: 0.5000
# ROUGE-2: 0.2727
# ROUGE-L: 0.4167
# Cosine Similarity: 0.3641
# --------------------------------------------------------------------------------
#
# Sample 97:
# User: I cannot find the instructions. Are they available on your website?
# Actual Assistant: HI.......the instruction booklet is included in the package. I did not understand them at first but once you get it, this thing really works. We use it on our Weimaraner Bama. If you need me to walk you through them, please let me know. Thanks.............Jeanne M. Dugger
# Generated Assistant: Yes, they are available on your website.
#
# Metrics:
# BLEU Score: 0.0002
# ROUGE-1: 0.0357
# ROUGE-2: 0.0000
# ROUGE-L: 0.0357
# Cosine Similarity: 0.2403
# --------------------------------------------------------------------------------
#
# Sample 98:
# User: will this lamp work in dog house safely?
# Actual Assistant: Yes, it should help significantly, but I would make sure that water cannot get to it. A metal globe/shield around the socket would be advisable and make sure it is high enough the dog's back or head will not hit it. A better way to heat your dog house might be a heat mat, like used by green houses to heat seed trays. Again be that plugs are protected from water, such as a dog shaking the water out of his/her coat! You would be surprised at how much water a dog can shake off! If you use the mat, make sure to put a barrier to keep it away from your dog's teeth, so they will not chew it. I suggest using a piece of cement backer board you can get at Lowe's or Home Depot, and a masonry cutting blade for your circular saw to cut it. Cut the backer board to fit inside your dog's house and place it on top of the heat mat, then put bedding on top if the backer board. It will keep him/her nice and warm. You can even put a thermostat in there to keep it from getting too warm. Most heat matts can reach temps of 100 degrees, which will not burn the dog, but may make it too warm to sleep on! Hope this helps. Again the lamp will work, but be sure it is protected from any water exposure, as it could be dangerous to your dog, if close enough to touch, beside throwing a breaker and destroying the lamp (ceramic heat element).
# Generated Assistant: Yes, it will work in a dog house. I have a dog who has a really large dog, and this is a great lamp.
#
# Metrics:
# BLEU Score: 0.0000
# ROUGE-1: 0.1216
# ROUGE-2: 0.0408
# ROUGE-L: 0.1014
# Cosine Similarity: 0.5262
# --------------------------------------------------------------------------------
#
# Sample 99:
# User: is this for a small dog? looking for one to fit a jack russell terrier, maybe 10 -12 pounds
# Actual Assistant: Yes. we use it on a 10 pound Dachshund. Will have to trim length of collar.
# Generated Assistant: I have a small dog and she fits in the middle of the cage.
#
# Metrics:
# BLEU Score: 0.0180
# ROUGE-1: 0.2000
# ROUGE-2: 0.0000
# ROUGE-L: 0.1333
# Cosine Similarity: 0.3683
# --------------------------------------------------------------------------------
#
# Sample 100:
# User: Will the Fluval FX6 be too powerful for a 105 gallon planted tank with angelfish. I am now using the XXL API and I constantly have to clean the thing
# Actual Assistant: The fx6 does have two outputs that put water back in the tank as strong as 2 small water jets would. But you can aim them up or down. If you aimed them up you would get good surface movement while not disturbing your plants or angels.
# Generated Assistant: I have a 105 gallon tank and the Fluval FX6 is not too powerful. It is a light weight, very efficient tank.
#
# Metrics:
# BLEU Score: 0.0065
# ROUGE-1: 0.1449
# ROUGE-2: 0.0000
# ROUGE-L: 0.0870
# Cosine Similarity: 0.5630
# --------------------------------------------------------------------------------
#
# Summary Statistics:
# count    5.000000
# mean     0.050895
# std      0.047376
# min      0.000000
# 25%      0.000440
# 50%      0.067990
# 75%      0.093023
# max      0.093023
# dtype: float64

# %%
# Validate model generation performance
from transformers import TextGenerationPipeline
import pandas as pd
import re
import nltk
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge_score import rouge_scorer
from sentence_transformers import SentenceTransformer, util

# Load sentence transformer model
sbert_model = SentenceTransformer('all-MiniLM-L6-v2')

# Initialize other models and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained(model_dir+'gpt2_open_ended')
tokenizer.pad_token = tokenizer.eos_token

model = GPT2LMHeadModel.from_pretrained(model_dir+'gpt2_open_ended')
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)
model.eval()

generator = TextGenerationPipeline(model=model, tokenizer=tokenizer, device=0 if device == 'cuda' else -1)

# Extract 100 validation samples
sample_size = 100
samples = val_open_ended_df.sample(n=sample_size, random_state=42).reset_index(drop=True)

# Separate user and assistant dialogues
def extract_user_assistant(dialogue):
    user_pattern = r'User:(.*?)\n'
    assistant_pattern = r'Assistant:(.*?)\n'
    
    user_match = re.search(user_pattern, dialogue, re.DOTALL)
    assistant_match = re.search(assistant_pattern, dialogue, re.DOTALL)
    
    user = user_match.group(1).strip() if user_match else ''
    assistant = assistant_match.group(1).strip() if assistant_match else ''
    
    return user, assistant

samples[['User', 'Assistant']] = samples['dialogue'].apply(
    lambda x: pd.Series(extract_user_assistant(x))
)

# Generate model replies
def generate_answer(question, tokenizer, model, device, max_length=150):
    prompt = f"User: {question}\nAssistant:"
    inputs = tokenizer.encode(prompt, return_tensors='pt').to(device)
    
    with torch.no_grad():
        outputs = model.generate(
            inputs,
            max_length=inputs.shape[1] + max_length,
            temperature=0.7,
            top_p=0.9,
            do_sample=True,
            eos_token_id=tokenizer.encode('\n')[0],
            pad_token_id=tokenizer.eos_token_id
        )
    
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    answer = generated_text.split("Assistant:")[-1].strip()
    answer = answer.split('\n')[0]
    
    return answer

samples['Generated_Assistant'] = samples['User'].apply(lambda x: generate_answer(x, tokenizer, model, device))

# Initialize ROUGE scorer
rouge = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

from bert_score import score as bert_score
def compute_metrics(row):
    actual = row['Assistant']
    generated = row['Generated_Assistant']
    
    # Calculate BLEU score
    smoothie = SmoothingFunction().method4
    bleu_score = sentence_bleu(
        [nltk.word_tokenize(actual.lower())],
        nltk.word_tokenize(generated.lower()),
        smoothing_function=smoothie
    )

    # Calculate ROUGE scores
    rouge_scores = rouge.score(actual, generated)
    
    # Calculate semantic similarity (Cosine Similarity)
    cosine_sim = util.pytorch_cos_sim(
        sbert_model.encode(actual, convert_to_tensor=True),
        sbert_model.encode(generated, convert_to_tensor=True)
    ).item()
    
    # Calculate BERTScore
    P, R, F1 = bert_score([generated], [actual], lang="en", verbose=False)
    bert_f1_score = F1.mean().item()
    
    # Return single values instead of Series
    return {
        'BLEU': float(bleu_score),  # Ensure float return type
        'ROUGE-1': float(rouge_scores['rouge1'].fmeasure),
        'ROUGE-2': float(rouge_scores['rouge2'].fmeasure),
        'ROUGE-L': float(rouge_scores['rougeL'].fmeasure),
        'Cosine_Similarity': float(cosine_sim),
        'BERTScore_F1': bert_f1_score
    }

# Calculate metrics for each sample
metrics_results = []
for idx, row in samples.iterrows():
    metrics = compute_metrics(row)
    metrics_results.append(metrics)

# Convert metrics to DataFrame and add to samples
metrics_df = pd.DataFrame(metrics_results)
samples = samples.assign(**metrics_df)

# Output results for each sample and format metrics
for i in range(sample_size):
    row = samples.iloc[i]
    print(f"\nSample {i+1}:")
    print(f"User: {row['User']}")
    print(f"Actual Assistant: {row['Assistant']}")
    print(f"Generated Assistant: {row['Generated_Assistant']}")
    print("\nMetrics:")
    
    # Convert Series to float format for output formatting
    metrics = {
        'BLEU': float(row['BLEU'].iloc[0] if isinstance(row['BLEU'], pd.Series) else row['BLEU']),
        'ROUGE-1': float(row['ROUGE-1'].iloc[0] if isinstance(row['ROUGE-1'], pd.Series) else row['ROUGE-1']),
        'ROUGE-2': float(row['ROUGE-2'].iloc[0] if isinstance(row['ROUGE-2'], pd.Series) else row['ROUGE-2']),
        'ROUGE-L': float(row['ROUGE-L'].iloc[0] if isinstance(row['ROUGE-L'], pd.Series) else row['ROUGE-L']),
        'Cosine_Similarity': float(row['Cosine_Similarity'].iloc[0] if isinstance(row['Cosine_Similarity'], pd.Series) else row['Cosine_Similarity']),
        'BERTScore_F1': float(row['BERTScore_F1'].iloc[0] if isinstance(row['BERTScore_F1'], pd.Series) else row['BERTScore_F1'])
    }
    
    # Output formatted metrics
    print(f"BLEU Score: {metrics['BLEU']:.4f}")
    print(f"ROUGE-1: {metrics['ROUGE-1']:.4f}")
    print(f"ROUGE-2: {metrics['ROUGE-2']:.4f}")
    print(f"ROUGE-L: {metrics['ROUGE-L']:.4f}")
    print(f"Cosine Similarity: {metrics['Cosine_Similarity']:.4f}")
    print(f"BERTScore (F1): {metrics['BERTScore_F1']:.4f}")
    print("-" * 80)

# Output summary statistics
print("\nSummary Statistics:")
metrics_columns = ['BLEU', 'ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'Cosine_Similarity', 'BERTScore_F1']
summary_stats = samples[metrics_columns].apply(lambda x: pd.to_numeric(x.iloc[0] if isinstance(x, pd.Series) else x)).describe()
print(summary_stats)
# Out:
# Device set to use cuda:0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Sample 1:
# User: How do you clean the litter box? Is there a liner that fits the box for easy kitty litter clean-up?
# Actual Assistant: I have never thought of a liner i just use the large metal scoop and i have it on a cabinet waist high because of my back and i have 6 cats so i only need one litter box i love it and would recommend to everyone
# Generated Assistant: The liner is small and does not fit the box. The liner fits easily on the box. I have a cat who does not like to use the liner and this litter box does not fit him. The liner is not very strong so I put it in the box and he does not like to use it.
#
# Metrics:
# BLEU Score: 0.0256
# ROUGE-1: 0.3429
# ROUGE-2: 0.0971
# ROUGE-L: 0.2286
# Cosine Similarity: 0.7120
# BERTScore (F1): 0.8594
# --------------------------------------------------------------------------------
#
# Sample 2:
# User: Does this product have to be used year round or simply during Flea, Mosquito, Tick season for seasonal areas? I traditionally only when needed.
# Actual Assistant: I use it year round. Because even if its snowing and cold you go to friends and family and could pick up an unknown passenger. Your family and friends even coworkers pets could have fleas and not know it. I take my dogs to dog parks and for walks where they encounter other dogs. I have not had a flea in 2 years before that I had one big costly flea infestation. Its cheaper to use this year round than cleaning up and ridding your house of a flea infestation.
# Generated Assistant: I do not have to use the year round product. I use it for my cat. I do not have to use the Mosquito for a year. I have a very small cat, and use the Mosquito every other year. It works well for her and her pup.
#
# Metrics:
# BLEU Score: 0.0312
# ROUGE-1: 0.3623
# ROUGE-2: 0.0735
# ROUGE-L: 0.2029
# Cosine Similarity: 0.6671
# BERTScore (F1): 0.8553
# --------------------------------------------------------------------------------
#
# Sample 3:
# User: What is the model number and warranty for this mat?
# Actual Assistant: Sorry I no longer have the box or any info on this. I do know it is still working just as well as it was when I got it. The pet still stay off the sofa even though its not there anymore. I just have black piece of cloth sitting there where it was. I now placed it in front of bedroom door to keep the pawing away at night.
# Generated Assistant: The model number is from the manufacturer. I have it in my box in my garage and it does not have a warranty on it. I do not have a dog so I cannot say for sure.
#
# Metrics:
# BLEU Score: 0.0269
# ROUGE-1: 0.2991
# ROUGE-2: 0.0381
# ROUGE-L: 0.1682
# Cosine Similarity: 0.4408
# BERTScore (F1): 0.8516
# --------------------------------------------------------------------------------
#
# Sample 4:
# User: Does this collar have a vibrate mode or just shock?
# Actual Assistant: No vibrate mode. However, there is a tone only mode. My dog learned very quickly that, once he heard the tone, he knew to correct his behavior. Also, I cannot even imagine going up to level 8. Level 3 did perfectly fine for my 60 lb. dog, and I really only had to do it a couple of times. Sorry, more info than you asked for, but I have always been against these collars until now. It really worked for me.
# Generated Assistant: I do not know, I do not know how this works. I have the collar and it works fine. I am not sure if it is the only thing that works for me, but I would not use it in a situation where I am going to use it.
#
# Metrics:
# BLEU Score: 0.0233
# ROUGE-1: 0.3231
# ROUGE-2: 0.0625
# ROUGE-L: 0.1538
# Cosine Similarity: 0.2481
# BERTScore (F1): 0.8556
# --------------------------------------------------------------------------------
#
# Sample 5:
# User: what heater works 50 or 100 watt
# Actual Assistant: I use a 50 watt
# Generated Assistant: The heater works 50 or 100 watts. I put it on a 70 gallon tank with a 30 gallon tank. It works perfectly.
#
# Metrics:
# BLEU Score: 0.0138
# ROUGE-1: 0.2857
# ROUGE-2: 0.0000
# ROUGE-L: 0.1429
# Cosine Similarity: 0.5070
# BERTScore (F1): 0.8740
# --------------------------------------------------------------------------------
#
# Sample 6:
# User: this fish tank suitable for any type of fish?
# Actual Assistant: Not for tropical fish as it has no heater. We used it for a beta (which technically should have a heater but was fine without) and also for goldfish.
# Generated Assistant: I have a big family of 10-15 lbs. this fish tank would fit them perfectly.
#
# Metrics:
# BLEU Score: 0.0169
# ROUGE-1: 0.1333
# ROUGE-2: 0.0465
# ROUGE-L: 0.0889
# Cosine Similarity: 0.3561
# BERTScore (F1): 0.8572
# --------------------------------------------------------------------------------
#
# Sample 7:
# User: Color name shows "tan" but photo looks like "cocoa"? I would buy stairs if they are truly Pet Gears "cocoa" color. I do not want the PG tan color
# Actual Assistant: I bought the item, I am a customer, not the seller, you should contact the seller for this matter. I do not know what page are you looking, but you should be able to switch between colours to see both of them. If you pass me the link, I might be able to help you out. But I repeat, I am a buyer such as you. BY THE WAY, stairs are reallly absolutely great, that is for sure. Oh, English is not my mother tonge so sorry if I do not make full sense. regards
# Generated Assistant: I do not know what you mean, I have seen the picture on the bottom of the post that says "Cocoa" and the color is "tan" but I have never seen anything like it on the bottom of the post.
#
# Metrics:
# BLEU Score: 0.0286
# ROUGE-1: 0.2519
# ROUGE-2: 0.0752
# ROUGE-L: 0.1630
# Cosine Similarity: 0.1478
# BERTScore (F1): 0.8394
# --------------------------------------------------------------------------------
#
# Sample 8:
# User: Is the bottom comfortable or should I buy two small beds to put inside?
# Actual Assistant: I think it would be comfortable. It is about 1/4-1/2" thick, firm but cushiony, and the top is really soft. My older cats do not seem to mind it, beyond the normal reaction to being in a carrier. I would probably add a blanket if our trips were longer than the 5 hours they typically are, though.
# Generated Assistant: I am not sure but the bottom is comfortable and the bed is not too large for me. I would not be able to put it in a large bed.
#
# Metrics:
# BLEU Score: 0.0253
# ROUGE-1: 0.3556
# ROUGE-2: 0.0682
# ROUGE-L: 0.2222
# Cosine Similarity: 0.2942
# BERTScore (F1): 0.8633
# --------------------------------------------------------------------------------
#
# Sample 9:
# User: I just bought this heater. Does it only turn the on button when it is heating up the tank? Or is the light always on when you plug it?
# Actual Assistant: The light is on when heating the tank and should turn off when it is at the set temperature.
# Generated Assistant: It does not turn on when the heater is heating up, but the light is always on. The light is always on. The only thing I would change is to change the heater's position to turn on the light. If you are using a heater, do not turn it on when it is heating up.
#
# Metrics:
# BLEU Score: 0.0447
# ROUGE-1: 0.3200
# ROUGE-2: 0.1370
# ROUGE-L: 0.2400
# Cosine Similarity: 0.7007
# BERTScore (F1): 0.8861
# --------------------------------------------------------------------------------
#
# Sample 10:
# User: What color is the product? Is the color of the part that Gulf Coast Pet Supplies ships the same blue that is in the product images?
# Actual Assistant: all the ones I have seen in store and youtube videos have been green with a white ball. [URL] I have seen other pictures online of more of a blue color track to include the manufacturer's website [URL]
# Generated Assistant: I am not sure if the product is actually Blue or Green or Purple. I have a Labrador mix, which is a color I have been using for years. I have not seen any color change that I cannot see, but it is a great product.
#
# Metrics:
# BLEU Score: 0.0267
# ROUGE-1: 0.3059
# ROUGE-2: 0.0723
# ROUGE-L: 0.2118
# Cosine Similarity: 0.4401
# BERTScore (F1): 0.8418
# --------------------------------------------------------------------------------
#
# Sample 11:
# User: My cat jumps on the wand long enough for the safety feature that turns off the motor kicks in. He cannot play with it more than a minute. Any help?
# Actual Assistant: I get my cat wound up with a feather on a pole type toy first, or a laser dot. Then I use the SmartyKat when I have tired out lol. You could try switching that around? When you cat stays on the wand, use the laser dot to get him to jump away, the turn off the dot and let him go after the SmartyKat again.
# Generated Assistant: My cat jumps on the wand long enough for the safety feature that turns off the motor kicks in. He cannot play with it more than a minute.
#
# Metrics:
# BLEU Score: 0.0180
# ROUGE-1: 0.2766
# ROUGE-2: 0.1087
# ROUGE-L: 0.1915
# Cosine Similarity: 0.6997
# BERTScore (F1): 0.8547
# --------------------------------------------------------------------------------
#
# Sample 12:
# User: Does this work with a metal hollow core door or does that mess with the magnetics?
# Actual Assistant: I put it in a metal hollow core door and it works fine for me. I have not had any problem with the magnets.
# Generated Assistant: It works great.
#
# Metrics:
# BLEU Score: 0.0008
# ROUGE-1: 0.1481
# ROUGE-2: 0.0800
# ROUGE-L: 0.1481
# Cosine Similarity: 0.0558
# BERTScore (F1): 0.8952
# --------------------------------------------------------------------------------
#
# Sample 13:
# User: Where can I find the manual for this product? I have mis-placed mine and I am having trouble programming it.
# Actual Assistant: You cannot.... I would see if maybe someone has a set up on YOU tube or I would contact the company itself. The manual is nowhere to be found online Without the manual you will not be able to set it up.
# Generated Assistant: You can order a manual for the Amazon product page
#
# Metrics:
# BLEU Score: 0.0020
# ROUGE-1: 0.1538
# ROUGE-2: 0.0000
# ROUGE-L: 0.1538
# Cosine Similarity: 0.6370
# BERTScore (F1): 0.8541
# --------------------------------------------------------------------------------
#
# Sample 14:
# User: How long did most of the orders take? Looking for a Halloween Costumes and it said up to 28 days. And where do you live? I live in PA
# Actual Assistant: Dear Customer, The order of Dogloveit usually delivered in 5-10 business days. But there is no such option for us to choose in Amazon's System but "17-28 days". So you will find the Estimated Delivery Date too long. In fact it is not ture. Most of our customers receive their package in 5 - 10 business days. You can check it in our feedback.
# Generated Assistant: I am living in the Southside. I have a 2 year old. My cat is very small. She has been in the crate for a few months. She is very happy. She loves the crate.
#
# Metrics:
# BLEU Score: 0.0061
# ROUGE-1: 0.1386
# ROUGE-2: 0.0000
# ROUGE-L: 0.0990
# Cosine Similarity: 0.1887
# BERTScore (F1): 0.8239
# --------------------------------------------------------------------------------
#
# Sample 15:
# User: how do you change the balls in the toy
# Actual Assistant: I plucked the old ones out and jammed the new ones in: brute force.
# Generated Assistant: I have one in my house that is not as big as mine. It is a small toy. I do not know how to make it work with my cat. I have the large one in the garage and it works fine.
#
# Metrics:
# BLEU Score: 0.0102
# ROUGE-1: 0.2500
# ROUGE-2: 0.0370
# ROUGE-L: 0.1786
# Cosine Similarity: 0.0514
# BERTScore (F1): 0.8470
# --------------------------------------------------------------------------------
#
# Sample 16:
# User: I am thinking of using this as a kitchen garbage can, so I need to know if it is easy to secure a plastic bag inside it, and what galsize works best.
# Actual Assistant: I purchased the square one. I did not need some so big. I would take measurements, height and width. The hole on top is smaller than a regular garbage can. So that might be a little problem. I think you are going to try to close the lid by screwing it on. Only makes sense but I think that is a problem of its own cuz screwing the lid on will also turn the garbage bad. Good Luck
# Generated Assistant: I use this as a trash can and it is easy to secure. The plastic bag is not too big and it can be easily secured. It does not come with a gasket but it is not too heavy. It is easy to put in and secure with the plastic bag.
#
# Metrics:
# BLEU Score: 0.0120
# ROUGE-1: 0.2481
# ROUGE-2: 0.0000
# ROUGE-L: 0.1705
# Cosine Similarity: 0.3972
# BERTScore (F1): 0.8556
# --------------------------------------------------------------------------------
#
# Sample 17:
# User: How long will it keep in the refrigerator once opened?
# Actual Assistant: I would not use it past the expiration date. Even though it is been refrigerated.
# Generated Assistant: It will stay in the refrigerator for about 6 months. I used it for a year and the refrigerator was working fine.
#
# Metrics:
# BLEU Score: 0.0175
# ROUGE-1: 0.3243
# ROUGE-2: 0.0571
# ROUGE-L: 0.2703
# Cosine Similarity: 0.4418
# BERTScore (F1): 0.8748
# --------------------------------------------------------------------------------
#
# Sample 18:
# User: How long do these typically last on the paws?
# Actual Assistant: I put them on all her front claws about 2 months ago and have had to replace 4 so far, they sporadically fall off while the nail grows and she tries to scratch. You just replace them as they come off. So far I would say they last about a month depending on your cats needing/scratching habits
# Generated Assistant: I have not tested them on my cats but they do not last for long. I have a small dog and she is a big chewer and she loves them. I use them on the sides of the house and they do not last long.
#
# Metrics:
# BLEU Score: 0.0215
# ROUGE-1: 0.3107
# ROUGE-2: 0.0396
# ROUGE-L: 0.1942
# Cosine Similarity: 0.6538
# BERTScore (F1): 0.8626
# --------------------------------------------------------------------------------
#
# Sample 19:
# User: Is it possible to replace the caster wheels if one broke? and if so what size do i need?
# Actual Assistant: I assume so. Either contact the company or check local hardware stores for the correct size. Depending what type of surface it sits on one could remove the wheels, replace them with rubber feet and slide furniture coasters under the feet when they require moving around. Probably less scuff to floors and wear on carpets
# Generated Assistant: I do not know, it is a little hard to find a replacement for the caster wheels. I do not know the size of the wheel.
#
# Metrics:
# BLEU Score: 0.0120
# ROUGE-1: 0.2716
# ROUGE-2: 0.0506
# ROUGE-L: 0.1728
# Cosine Similarity: 0.6482
# BERTScore (F1): 0.8590
# --------------------------------------------------------------------------------
#
# Sample 20:
# User: 1) How often does it need replacing in a 10 gallon tank? 2) From the image, I cannot tell where the airline tube connects to this filter? Thanks!
# Actual Assistant: I have used them for over a year now and all I do is rinse mine with water every 2 weeks, the air hose connects at the too of the filter behind where the bubbles are released.
# Generated Assistant: I have replaced the filter with the filter, and have not had to replace the filter again.
#
# Metrics:
# BLEU Score: 0.0193
# ROUGE-1: 0.2963
# ROUGE-2: 0.0769
# ROUGE-L: 0.2222
# Cosine Similarity: 0.3659
# BERTScore (F1): 0.8670
# --------------------------------------------------------------------------------
#
# Sample 21:
# User: What is dimensions ?
# Actual Assistant: 22-23 inches in circumference Height is variable. It goes down and back up. my dog loves to tunnel herself inside of it.
# Generated Assistant: It is about 8" long, 1.5" high, and it is a 12" long. It is a good size for a dog that is about 6-7 pounds. I think that it is a good size for a dog that weighs around 12 pounds.
#
# Metrics:
# BLEU Score: 0.0182
# ROUGE-1: 0.1493
# ROUGE-2: 0.0000
# ROUGE-L: 0.1194
# Cosine Similarity: 0.4987
# BERTScore (F1): 0.8514
# --------------------------------------------------------------------------------
#
# Sample 22:
# User: when I choose the 3 mode description says only blue light &amp; white/blue so two modes? I want white only and blue only.
# Actual Assistant: Hi dear sorry for the late respon. What was written in the description, the intention was to have 3 modes 1. white light 2. Light Blue 3. White with blue light
# Generated Assistant: Yes it is blue.
#
# Metrics:
# BLEU Score: 0.0002
# ROUGE-1: 0.0571
# ROUGE-2: 0.0000
# ROUGE-L: 0.0571
# Cosine Similarity: 0.3594
# BERTScore (F1): 0.8492
# --------------------------------------------------------------------------------
#
# Sample 23:
# User: I would like to get one for my dog, she is a Beagle, how would I go about measuring her to see what size she would need? She is about 25lbs. Thanks in advance.
# Actual Assistant: According to the company website, a 25lb dog should use a Medium. However, there is a sizing chart on the company website, [URL]
# Generated Assistant: I have not measured her, but I think she would fit. I would not know for sure.
#
# Metrics:
# BLEU Score: 0.0099
# ROUGE-1: 0.0000
# ROUGE-2: 0.0000
# ROUGE-L: 0.0000
# Cosine Similarity: 0.1879
# BERTScore (F1): 0.8503
# --------------------------------------------------------------------------------
#
# Sample 24:
# User: In your opinion will a medium size fit a standard size schnauzer puppy 30lbs
# Actual Assistant: My springer is 52 lbs and it fits him about right. Looks like you might be right in between sizes.
# Generated Assistant: I have a medium and it fits him perfectly. He is a good fit for my small and medium sized dogs.
#
# Metrics:
# BLEU Score: 0.1226
# ROUGE-1: 0.3415
# ROUGE-2: 0.1538
# ROUGE-L: 0.2439
# Cosine Similarity: 0.5097
# BERTScore (F1): 0.8879
# --------------------------------------------------------------------------------
#
# Sample 25:
# User: I have a 200 watt it set St 82 my tank water stays cold
# Actual Assistant: what size is your tank? I have a 300 watt in my 90 gallon saltwater . Temperature set at 78 and it stays at 78. I ran it at 82 degrees when it was cycling
# Generated Assistant: My tank is on a 2 gallon (1 gallon) tank and I do not have to worry about it freezing. It is the only tank I have on my tank. I have it set for 2 weeks. I have no problems with freezing water. I would not recommend it.
#
# Metrics:
# BLEU Score: 0.0189
# ROUGE-1: 0.3133
# ROUGE-2: 0.0494
# ROUGE-L: 0.1928
# Cosine Similarity: 0.3603
# BERTScore (F1): 0.8617
# --------------------------------------------------------------------------------
#
# Sample 26:
# User: What kind of treats/food do you use with this?
# ...
# Generated Assistant: I have a small dog and I would go with the collar that is the best for him. It is the same collar I used for my Labrador retriever.
#
# Metrics:
# BLEU Score: 0.0003
# ROUGE-1: 0.2041
# ROUGE-2: 0.0515
# ROUGE-L: 0.1327
# Cosine Similarity: 0.6422
# BERTScore (F1): 0.8525
# --------------------------------------------------------------------------------
#
# Sample 79:
# User: is it true you cannot turn the light off on this? can you use the light w/o the bubbler? Only need some blue led lighting in the existing cresent ta
# Actual Assistant: Light has no in-line switch, but I have mine on a timer Bubbler is separate, you have to hook up an air pump. I love the effect of both the bubbles and the light
# Generated Assistant: Yes, it works. The bulb will turn on when the light goes out.
#
# Metrics:
# BLEU Score: 0.0129
# ROUGE-1: 0.1667
# ROUGE-2: 0.0435
# ROUGE-L: 0.1250
# Cosine Similarity: 0.2692
# BERTScore (F1): 0.8610
# --------------------------------------------------------------------------------
#
# Sample 80:
# User: what is the difference between a 7 blade and 7f blade?
# Actual Assistant: 7F is a finish blade and a 7 is a skip tooth
# Generated Assistant: The 7f blade is the most durable blade on the market. It is the best blade on the market for the price. It has the same size blade as the 7 blade. It is very durable and can be easily transported to your local hardware store. It is also a great alternative to a wood cutting tool.
#
# Metrics:
# BLEU Score: 0.0085
# ROUGE-1: 0.2319
# ROUGE-2: 0.0000
# ROUGE-L: 0.1739
# Cosine Similarity: 0.6029
# BERTScore (F1): 0.8331
# --------------------------------------------------------------------------------
#
# Sample 81:
# User: Does the feeder limit the quantity of dog food or do you rely on the dog to get full and stop eating?
# Actual Assistant: No limits on the amount of food. This worried me some too but others had said their digs did not, and though my dog was a food fanatic he also did not overhead, but did eat more the first few weeks. No he goes a takes a few bites at all different times, but seems to eat less now that he did before putting this in. But the thing about this one is it will leak if placed in a place where it rains. The lid is not properly designed to overlap at the top. So either mount where rain will not hit or drain onto it, or get the plastic bergen one that is similar shape but plastic.
# Generated Assistant: I use it as a snack for my dogs, and it is not a big deal. My only problem is that I do not have enough dog food in my home, so I do not know how much the feeder would be able to handle.
#
# Metrics:
# BLEU Score: 0.0056
# ROUGE-1: 0.2195
# ROUGE-2: 0.0247
# ROUGE-L: 0.1098
# Cosine Similarity: 0.6063
# BERTScore (F1): 0.8450
# --------------------------------------------------------------------------------
#
# Sample 82:
# User: Does this product contain any plastic? What material is it made up of?
# Actual Assistant: I think it is rubber, it is pretty near indestructible
# Generated Assistant: The plastic is made up of two layers of polystyrene and is coated with a reflective coating that can be removed by the user. The plastic is made up of polystyrene and is coated with a reflective coating that can be removed by the user.
#
# Metrics:
# BLEU Score: 0.0076
# ROUGE-1: 0.0727
# ROUGE-2: 0.0000
# ROUGE-L: 0.0727
# Cosine Similarity: 0.3659
# BERTScore (F1): 0.8438
# --------------------------------------------------------------------------------
#
# Sample 83:
# User: How many panels come in the set?
# Actual Assistant: 8 Panels exactly as shown
# Generated Assistant: There are only three panels. One is for a 2 inch long panel and one for a 4 inch long panel.
#
# Metrics:
# BLEU Score: 0.0116
# ROUGE-1: 0.0769
# ROUGE-2: 0.0000
# ROUGE-L: 0.0769
# Cosine Similarity: 0.6564
# BERTScore (F1): 0.8267
# --------------------------------------------------------------------------------
#
# Sample 84:
# User: i do not see "contact seller" any where on my order, where exactly do you put the info?
# Actual Assistant: If you cannot find the "Contact Seller" link, do not worry, as soon as we receive an order that does not contain the engraving information, we will contact the customer through Amazon to get it.
# Generated Assistant: The link is on the product page. The contact seller is the one that I bought the product from.
#
# Metrics:
# BLEU Score: 0.0147
# ROUGE-1: 0.2593
# ROUGE-2: 0.0769
# ROUGE-L: 0.1852
# Cosine Similarity: 0.6141
# BERTScore (F1): 0.8648
# --------------------------------------------------------------------------------
#
# Sample 85:
# User: I like to have the composition of EPAKITIN
# Actual Assistant: It contains Lactose,Calcium Carbonate, Chitosan and Hydrolyzed Soy Protein
# Generated Assistant: I do not think it is necessary. I have used it on my Labrador and he is very happy.
#
# Metrics:
# BLEU Score: 0.0149
# ROUGE-1: 0.1379
# ROUGE-2: 0.0000
# ROUGE-L: 0.1379
# Cosine Similarity: 0.0278
# BERTScore (F1): 0.8174
# --------------------------------------------------------------------------------
#
# Sample 86:
# User: The product comes with one bag. This bag is supposed to last 3-6 months?
# Actual Assistant: I have four cats, all indoor, and one bag lasts me a little more than a month. I would say 5-6 weeks.
# Generated Assistant: The bag does not last 3 months. I bought it in September and it is still in good condition.
#
# Metrics:
# BLEU Score: 0.0281
# ROUGE-1: 0.2381
# ROUGE-2: 0.0500
# ROUGE-L: 0.1905
# Cosine Similarity: 0.5310
# BERTScore (F1): 0.8811
# --------------------------------------------------------------------------------
#
# Sample 87:
# User: I have a toy poodle-will the blade work without nicking or burning his face? Will it also work on clipping feet?
# Actual Assistant: I have a Standard Poodle that hates to have his feet clipped. I struggled with regular size clippers for year before I purchased the MiniArco. I love it! It has not changed the fact that he still hates to have his feet clipped but it is much easier to do the job. I also use it on his face. I find that the blade does not get as hot as regular clipper blades. So far, I have not had any nicking or burning. Good luck with your Toy!
# Generated Assistant: Yes, it will work on clipping.
#
# Metrics:
# BLEU Score: 0.0000
# ROUGE-1: 0.0638
# ROUGE-2: 0.0000
# ROUGE-L: 0.0426
# Cosine Similarity: 0.3591
# BERTScore (F1): 0.8333
# --------------------------------------------------------------------------------
#
# Sample 88:
# User: What are the two different types of heating?
# Actual Assistant: One is a 24 hour packet of chemicals which when combined produce heat for 24 hours. The other is a packet that can be filled with rice and microwaved for 30 to 45 seconds that will stay warm for 15 minutes or so, which is long enough for a pup to get to sleep. Which ever one you use is inserted into the pocket in the belly of the pup and closed with the velcro.
# Generated Assistant: It is the same type of heating as the one shown in the picture. I have a 2 year old German Shepherd and this heater is very efficient. The one on my little one is the "hot" type.
#
# Metrics:
# BLEU Score: 0.0144
# ROUGE-1: 0.2655
# ROUGE-2: 0.0360
# ROUGE-L: 0.1770
# Cosine Similarity: 0.4113
# BERTScore (F1): 0.8513
# --------------------------------------------------------------------------------
#
# Sample 89:
# User: Um, I know this sounds dumb, but how do you remove the bowl from the holder. It seems to be in there pretty tight. Snappy it are not.
# Actual Assistant: The bowl slides straight into the holder, which is bolted onto the cage. The bowl is held firmly enough that the animal will not knock it out accidentally, but can be removed by an adult human. I would not do it while there is water in the bowl, it will probably spill if you try.
# Generated Assistant: I removed it from the holder and put it in a plastic bag with a plastic clip.
#
# Metrics:
# BLEU Score: 0.0042
# ROUGE-1: 0.1944
# ROUGE-2: 0.0286
# ROUGE-L: 0.1111
# Cosine Similarity: 0.3566
# BERTScore (F1): 0.8628
# --------------------------------------------------------------------------------
#
# Sample 90:
# User: how much water will be evaporate with this cover
# Actual Assistant: I own numerous reptiles, and I have worked in a pet store for seven years. Screen covers such as this one do absolutely nothing to prevent water loss due to evaporation. The stronger a heat source on the cage and the lower the ambient humidity of the room where the cage is, the faster this evaporation will occur. This can be mitigated by covering a portion of the lid (a safe distance from heat lamps or emmiters) with plexiglass from your local hardware store, or with the addition of an automatic misting system. If you are using it as a fish tank cover you should just top off more frequently. With fish tanks the faster evaporation rate is often actually good for your tank; the gas exchange that accompanies the evaporation us your tank "breathing".
# Generated Assistant: The water will be evaporate at about the same rate as the water that was in the cover.
#
# Metrics:
# BLEU Score: 0.0000
# ROUGE-1: 0.1699
# ROUGE-2: 0.0000
# ROUGE-L: 0.1046
# Cosine Similarity: 0.4340
# BERTScore (F1): 0.8365
# --------------------------------------------------------------------------------
#
# Sample 91:
# User: Which type of filter does this zen fountain take? Premium? Original?
# Actual Assistant: I use the Premium...
# Generated Assistant: I do not know. I do not use this for my water quality but for my pet's taste. I do use it for my water quality. I use it for my pet's taste.
#
# Metrics:
# BLEU Score: 0.0161
# ROUGE-1: 0.1026
# ROUGE-2: 0.0541
# ROUGE-L: 0.1026
# Cosine Similarity: 0.0454
# BERTScore (F1): 0.8333
# --------------------------------------------------------------------------------
#
# Sample 92:
# User: I have a Basset Hound that ways 86 lbs and has a girth of 35 inches neck is 24 inches should I get the large or extra large?
# Actual Assistant: Get the large vest. We got the x-large and it is to big for our lab who weighs 90lbs.
# Generated Assistant: I would not hesitate to go with the medium. My dogs are a bit overweight and my medium is small. I am very happy with my medium.
#
# Metrics:
# BLEU Score: 0.0146
# ROUGE-1: 0.1702
# ROUGE-2: 0.0000
# ROUGE-L: 0.1277
# Cosine Similarity: 0.4454
# BERTScore (F1): 0.8760
# --------------------------------------------------------------------------------
#
# Sample 93:
# User: what is the flap size?
# Actual Assistant: that door is 15 x 20 and its the one I have leaving my patio. I would never have one like that placed on a door to the house. it is not too weather proof or insect proof and does not seal too well. as far as my home door, I used a dog mate large which I also ordered from amazon and it has a hard plastic insulated door which seals well. its large size(which I believe is the biggest they sell) is 11 3/4 by 14 but meets the needs of the average large dog. my shepherd stands 27 inches tall at mid back and weighs 93 pounds and uses it with no problem. if this door is leaving your home and not patio I would check into the dog mate door. also I installed it with lower opening approx. 9 1/2 inches from bottom of door. the dog mate doors will usually last for years. hope this helped
# Generated Assistant: I have a small one and I have to say it fits my cat like a glove.
#
# Metrics:
# BLEU Score: 0.0000
# ROUGE-1: 0.1326
# ROUGE-2: 0.0112
# ROUGE-L: 0.0884
# Cosine Similarity: 0.2449
# BERTScore (F1): 0.8480
# --------------------------------------------------------------------------------
#
# Sample 94:
# User: Do you use critter litter with this or just regular bedding? I have read mixed reviews on the critter litter for rabbits
# Actual Assistant: I use paper litter for my rats in it. do not know if that helps or not.
# Generated Assistant: I do use this litter for rabbits. I have a cat who has a large litterbox in her bedroom. It is perfect for her.
#
# Metrics:
# BLEU Score: 0.0328
# ROUGE-1: 0.3415
# ROUGE-2: 0.0513
# ROUGE-L: 0.2927
# Cosine Similarity: 0.5867
# BERTScore (F1): 0.8826
# --------------------------------------------------------------------------------
#
# Sample 95:
# User: Is Andis 60105 run quiet or are they loud.
# Actual Assistant: It makes some noise but not loud compared to others I have tried. I use it on three different dogs and the noise does not scare them.
# Generated Assistant: They are quiet but I have a cat and it is getting to the point where I cannot hear them. My cat can hear them but is not so loud. I have had them for about 6 months now.
#
# Metrics:
# BLEU Score: 0.0316
# ROUGE-1: 0.3333
# ROUGE-2: 0.0312
# ROUGE-L: 0.2121
# Cosine Similarity: 0.4690
# BERTScore (F1): 0.8827
# --------------------------------------------------------------------------------
#
# Sample 96:
# User: where is it made?
# Actual Assistant: I am sure it is in the US, but I cannot remember where--back east I think. NOT China. NEVER China!!
# Generated Assistant: It is made in China.
#
# Metrics:
# BLEU Score: 0.0037
# ROUGE-1: 0.3077
# ROUGE-2: 0.0833
# ROUGE-L: 0.3077
# Cosine Similarity: 0.5890
# BERTScore (F1): 0.8599
# --------------------------------------------------------------------------------
#
# Sample 97:
# User: Is this litter scented or unscented? Sound like dust is not a problem.
# Actual Assistant: There was a mild scent, and yes, dust was not a problem like other litters.
# Generated Assistant: It smells like smoke and I have never had it. I have used it for about 3 years. The smell is not very pleasant. I have used it for about 2 years and I do not have any complaints.
#
# Metrics:
# BLEU Score: 0.0097
# ROUGE-1: 0.1111
# ROUGE-2: 0.0000
# ROUGE-L: 0.0741
# Cosine Similarity: 0.3703
# BERTScore (F1): 0.8620
# --------------------------------------------------------------------------------
#
# Sample 98:
# User: what are the dimensions of this item??
# Actual Assistant: Under product details, it states that the product dimensions are 22.2 x 12.5 x 23.2.
# Generated Assistant: I am not sure what you are looking for. I have a 5 gallon tank and I have a 1 gallon water heater. I purchased this as a replacement for my old one and have never had to replace the heater.
#
# Metrics:
# BLEU Score: 0.0089
# ROUGE-1: 0.1017
# ROUGE-2: 0.0000
# ROUGE-L: 0.0678
# Cosine Similarity: 0.1010
# BERTScore (F1): 0.8335
# --------------------------------------------------------------------------------
#
# Sample 99:
# User: Does this come with two bowls or one? I see two answers to this exact question but both answers are different.
# Actual Assistant: My purchase came with one bowl.
# Generated Assistant: Both bowls come with a bowl and one bowl. The bowls come with a bowl and one bowl. The bowls come with a bowl and one bowl. The bowls come with a bowl and one bowl.
#
# Metrics:
# BLEU Score: 0.0341
# ROUGE-1: 0.1429
# ROUGE-2: 0.0500
# ROUGE-L: 0.1429
# Cosine Similarity: 0.7670
# BERTScore (F1): 0.8730
# --------------------------------------------------------------------------------
#
# Sample 100:
# User: why do you have pet products made in CHINA???
# Actual Assistant: Because Chicken treats from us runs min $ 1.00 Lb. But now that they have raised there prices so much i have quite using this Brand.
# Generated Assistant: My husband and I both bought this and it is the best we have ever had. We have had it for about 2 years and it works great for our dogs. They love it.
#
# Metrics:
# BLEU Score: 0.0127
# ROUGE-1: 0.1667
# ROUGE-2: 0.0000
# ROUGE-L: 0.0667
# Cosine Similarity: 0.1414
# BERTScore (F1): 0.8434
# --------------------------------------------------------------------------------
#
# Summary Statistics:
# count    6.000000
# mean     0.377609
# std      0.337641
# min      0.025646
# 25%      0.129958
# 50%      0.285714
# 75%      0.619750
# max      0.859448
# dtype: float64
